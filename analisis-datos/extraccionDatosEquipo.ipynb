# %%
import pandas as pd

# %%
indicadoresEquipoHistoricoModelo = pd.read_csv('indicadoresEquipoHistoricoModelo-bundesliga-2024.csv',sep=",")
indicadoresEquipoHistoricoModelo

# %%
partidos = pd.read_csv('partidos-bundesliga-2024.csv',sep=",")
partidos= partidos.loc[(partidos['finalizado'] == 1) ]   
partidos

# %%
equipos = pd.read_csv('equipos-bundesliga-2024.csv',sep=",")
equipos

# %%
dataframe_indicadores_equipos=pd.DataFrame(columns=['id_equipo','nombre',
'porcentaje ganados en general',
'porcentaje empatados en general',
'porcentaje perdidos en general',
'proporcion puntos en general',

'porcentaje mas 1,5 en general',
'porcentaje mas 2,5 en general',
'porcentaje mas 3,5 en general',
'porcentaje mas 4,5 en general',

'proporcion goles totales en general',
'proporcion goles marcados en general',
'proporcion goles encajados en general',

'porcentaje mas 0,5 marcados en general',
'porcentaje mas 1,5 marcados en general',
'porcentaje mas 2,5 marcados en general',
'porcentaje mas 0,5 encajados en general',
'porcentaje mas 1,5 encajados en general',
'porcentaje mas 2,5 encajados en general',

'proporcion amarillas en general',
'proporcion rojas en general',
'proporcion cambios en general',
'proporcion posesion en general',
'proporcion total tiros en general',
'proporcion corners a favor en general',
'proporcion corners en contra en general',

'proporcion cambios lesionados en general',
'proporcion cambios amarillas en general',
'proporcion cambios goleadores en general',
'proporcion cambios asistentes en general',
'media cambios minutos en general',

'proporcion cambios delanteros a centrocampistas en general',
'proporcion cambios delanteros a defensas en general',
'proporcion cambios centrocampistas a delanteros en general',
'proporcion cambios centrocampistas a defensas en general',
'proporcion cambios defensas a delanteros en general',
'proporcion cambios defensas a centrocampistas en general',

'proporcion cambios antes descanso en general',
'proporcion cambios 45 a 60 en general',
'proporcion cambios 61 a 75 en general',
'proporcion cambios 76 a final en general',

'proporcion cambios alineacion defensa en general',
'proporcion cambios alineacion centrocampista en general',
'proporcion cambios alineacion delantero en general'
])

print(dataframe_indicadores_equipos.shape)

# %%
indicadoresEquipoHistoricoModelo=pd.merge(indicadoresEquipoHistoricoModelo, partidos, on='id_partido', how='inner')
indicadoresEquipoHistoricoModelo

# %%
for index, row in equipos.iterrows():
            id_equipo = row['id_equipo']
            nombre = row['nombre']
            ultima_fila_local = indicadoresEquipoHistoricoModelo[(indicadoresEquipoHistoricoModelo["id_equipo_local"] == id_equipo) ].iloc[-1]
            ultima_fila_visitante = indicadoresEquipoHistoricoModelo[(indicadoresEquipoHistoricoModelo["id_equipo_visitante"] == id_equipo) ].iloc[-1]

            if ultima_fila_local["fecha"]<ultima_fila_visitante["fecha"]:
                        conjunto=[id_equipo,nombre,ultima_fila_visitante['porcentaje visitante ganados en general'],ultima_fila_visitante['porcentaje visitante empatados en general'],ultima_fila_visitante['porcentaje visitante perdidos en general'],
                        ultima_fila_visitante['proporcion visitante puntos en general'],   

                        ultima_fila_visitante['porcentaje visitante mas 1,5 en general'],ultima_fila_visitante['porcentaje visitante mas 2,5 en general'],ultima_fila_visitante['porcentaje visitante mas 3,5 en general'],ultima_fila_visitante['porcentaje visitante mas 4,5 en general'],
                        
                        ultima_fila_visitante['proporcion visitante goles totales en general'],ultima_fila_visitante['proporcion visitante goles marcados en general'],ultima_fila_visitante['proporcion visitante goles encajados en general'],

                        ultima_fila_visitante['porcentaje visitante mas 0,5 marcados en general'],ultima_fila_visitante['porcentaje visitante mas 1,5 marcados en general'],ultima_fila_visitante['porcentaje visitante mas 2,5 marcados en general'],ultima_fila_visitante['porcentaje visitante mas 0,5 encajados en general'],
                        ultima_fila_visitante['porcentaje visitante mas 1,5 encajados en general'],
                        ultima_fila_visitante['porcentaje visitante mas 2,5 encajados en general'],

                        ultima_fila_visitante['proporcion visitante amarillas en general'],ultima_fila_visitante['proporcion visitante rojas en general'],ultima_fila_visitante['proporcion visitante cambios en general'],ultima_fila_visitante['proporcion visitante posesion en general'],ultima_fila_visitante['proporcion visitante total tiros en general'],ultima_fila_visitante['proporcion visitante corners a favor en general'],ultima_fila_visitante['proporcion visitante corners en contra en general'],
                        
                        ultima_fila_visitante['proporcion visitante cambios lesionados en general'],ultima_fila_visitante['proporcion visitante cambios amarillas en general'],ultima_fila_visitante['proporcion visitante cambios goleadores en general'],ultima_fila_visitante['proporcion visitante cambios asistentes en general'],ultima_fila_visitante['media visitante cambios minutos en general'],

                        ultima_fila_visitante['proporcion visitante cambios delanteros a centrocampistas en general'],
                        ultima_fila_visitante['proporcion visitante cambios delanteros a defensas en general'],
                        ultima_fila_visitante['proporcion visitante cambios centrocampistas a delanteros en general'],
                        ultima_fila_visitante['proporcion visitante cambios centrocampistas a defensas en general'],
                        ultima_fila_visitante['proporcion visitante cambios defensas a delanteros en general'],
                        ultima_fila_visitante['proporcion visitante cambios defensas a centrocampistas en general'],

                        ultima_fila_visitante['proporcion visitante cambios antes descanso en general'],
                        ultima_fila_visitante['proporcion visitante cambios 45 a 60 en general'],
                        ultima_fila_visitante['proporcion visitante cambios 61 a 75 en general'],
                        ultima_fila_visitante['proporcion visitante cambios 76 a final en general'],

                        ultima_fila_visitante['proporcion visitante cambios alineacion defensa en general'],
                        ultima_fila_visitante['proporcion visitante cambios alineacion centrocampista en general'],
                        ultima_fila_visitante['proporcion visitante cambios alineacion delantero en general']]
                        
                        dataframe_indicadores_equipos.loc[len(dataframe_indicadores_equipos)]=conjunto
                        
            else:
                        conjunto=[id_equipo,nombre,
                        ultima_fila_local['porcentaje local ganados en general'],ultima_fila_local['porcentaje local empatados en general'],ultima_fila_local['porcentaje local perdidos en general'],
                        ultima_fila_local['proporcion local puntos en general'],   

                        ultima_fila_local['porcentaje local mas 1,5 en general'],ultima_fila_local['porcentaje local mas 2,5 en general'],ultima_fila_local['porcentaje local mas 3,5 en general'],ultima_fila_local['porcentaje local mas 4,5 en general'],
                        
                        ultima_fila_local['proporcion local goles totales en general'],ultima_fila_local['proporcion local goles marcados en general'],ultima_fila_local['proporcion local goles encajados en general'],

                        ultima_fila_local['porcentaje local mas 0,5 marcados en general'],ultima_fila_local['porcentaje local mas 1,5 marcados en general'],ultima_fila_local['porcentaje local mas 2,5 marcados en general'],ultima_fila_local['porcentaje local mas 0,5 encajados en general'],
                        ultima_fila_local['porcentaje local mas 1,5 encajados en general'],
                        ultima_fila_local['porcentaje local mas 2,5 encajados en general'],

                        ultima_fila_local['proporcion local amarillas en general'],ultima_fila_local['proporcion local rojas en general'],ultima_fila_local['proporcion local cambios en general'],ultima_fila_local['proporcion local posesion en general'],ultima_fila_local['proporcion local total tiros en general'],ultima_fila_local['proporcion local corners a favor en general'],ultima_fila_local['proporcion local corners en contra en general'],
                        
                        ultima_fila_local['proporcion local cambios lesionados en general'],ultima_fila_local['proporcion local cambios amarillas en general'],ultima_fila_local['proporcion local cambios goleadores en general'],ultima_fila_local['proporcion local cambios asistentes en general'],ultima_fila_local['media local cambios minutos en general'],

                        ultima_fila_local['proporcion local cambios delanteros a centrocampistas en general'],
                        ultima_fila_local['proporcion local cambios delanteros a defensas en general'],
                        ultima_fila_local['proporcion local cambios centrocampistas a delanteros en general'],
                        ultima_fila_local['proporcion local cambios centrocampistas a defensas en general'],
                        ultima_fila_local['proporcion local cambios defensas a delanteros en general'],
                        ultima_fila_local['proporcion local cambios defensas a centrocampistas en general'],

                        ultima_fila_local['proporcion local cambios antes descanso en general'],
                        ultima_fila_local['proporcion local cambios 45 a 60 en general'],
                        ultima_fila_local['proporcion local cambios 61 a 75 en general'],
                        ultima_fila_local['proporcion local cambios 76 a final en general'],

                        ultima_fila_local['proporcion local cambios alineacion defensa en general'],
                        ultima_fila_local['proporcion local cambios alineacion centrocampista en general'],
                        ultima_fila_local['proporcion local cambios alineacion delantero en general']]
                        
                        dataframe_indicadores_equipos.loc[len(dataframe_indicadores_equipos)]=conjunto

# %%
dataframe_indicadores_equipos.to_csv('datosIndicadoresEquipos-bundesliga-2024.csv', index=False)
