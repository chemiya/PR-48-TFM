# %%
import numpy as np
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
import tensorflow as tf
import pandas as pd
from sklearn.preprocessing import OneHotEncoder
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from google.colab import drive

# %%
drive.mount('/content/drive')
path = '/content/drive/MyDrive/Colab Notebooks/TFM/datosAgrupadosV1.csv'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv(path,sep=";")
df
# Out:
#       id_indicadores_equipo_prepartido  id_partido  \
# 0                                 90.0        95.0
# 1                                 91.0        97.0
# 2                                 92.0        94.0
# 3                                 93.0        98.0
# 4                                 94.0        92.0
# ...                                ...         ...
# 1725                             375.0       754.0
# 1726                             376.0       755.0
# 1727                             377.0       756.0
# 1728                             378.0       757.0
# 1729                             379.0       759.0
#
#       porcentaje local ganados en sitio  porcentaje local ganados en general  \
# 0                                  0.00                                 0.00
# 1                                 75.00                                55.56
# 2                                 75.00                                66.67
# 3                                 25.00                                33.33
# 4                                 50.00                                44.44
# ...                                 ...                                  ...
# 1725                              66.67                                51.35
# 1726                              33.33                                27.03
# 1727                              44.44                                29.73
# 1728                              16.67                                13.51
# 1729                              55.56                                37.84
#
#       porcentaje local empatados en sitio  \
# 0                                   50.00
# 1                                    0.00
# 2                                   25.00
# 3                                   25.00
# 4                                   25.00
# ...                                   ...
# 1725                                11.11
# 1726                                33.33
# 1727                                16.67
# 1728                                27.78
# 1729                                 5.56
#
#       porcentaje local empatados en general  \
# 0                                     44.44
# 1                                      0.00
# 2                                     22.22
# 3                                     11.11
# 4                                     22.22
# ...                                     ...
# 1725                                  16.22
# 1726                                  27.03
# 1727                                  16.22
# 1728                                  24.32
# 1729                                  21.62
#
#       porcentaje local perdidos en sitio  \
# 0                                  50.00
# 1                                  25.00
# 2                                   0.00
# 3                                  50.00
# 4                                  25.00
# ...                                  ...
# 1725                               22.22
# 1726                               33.33
# 1727                               38.89
# 1728                               55.56
# 1729                               38.89
#
#       porcentaje local perdidos en general  \
# 0                                    55.56
# 1                                    44.44
# 2                                    11.11
# 3                                    55.56
# 4                                    33.33
# ...                                    ...
# 1725                                 32.43
# 1726                                 45.95
# 1727                                 54.05
# 1728                                 62.16
# 1729                                 40.54
#
#       porcentaje visitante ganados en sitio  \
# 0                                     75.00
# 1                                     50.00
# 2                                      0.00
# 3                                      0.00
# 4                                     25.00
# ...                                     ...
# 1725                                  55.56
# 1726                                  72.22
# 1727                                  16.67
# 1728                                  16.67
# 1729                                  16.67
#
#       porcentaje visitante ganados en general  ...  \
# 0                                       77.78  ...
# 1                                       44.44  ...
# 2                                       11.11  ...
# 3                                       11.11  ...
# 4                                       44.44  ...
# ...                                       ...  ...
# 1725                                    62.16  ...
# 1726                                    75.68  ...
# 1727                                    27.03  ...
# 1728                                    27.03  ...
# 1729                                    35.14  ...
#
#       proporcion visitante cambios alineacion centrocampista en sitio  \
# 0                                                  2.00
# 1                                                  1.50
# 2                                                  1.25
# 3                                                  0.50
# 4                                                  1.50
# ...                                                 ...
# 1725                                               1.33
# 1726                                               1.17
# 1727                                               0.83
# 1728                                               0.67
# 1729                                               0.50
#
#       proporcion visitante cambios alineacion centrocampista en general  \
# 0                                                  2.11
# 1                                                  1.44
# 2                                                  1.00
# 3                                                  0.56
# 4                                                  1.67
# ...                                                 ...
# 1725                                               1.24
# 1726                                               1.14
# 1727                                               0.89
# 1728                                               0.62
# 1729                                               0.62
#
#       proporcion local cambios alineacion delantero sitio  \
# 0                                                  1.25
# 1                                                  1.25
# 2                                                  1.50
# 3                                                  1.25
# 4                                                  1.00
# ...                                                 ...
# 1725                                               0.89
# 1726                                               1.11
# 1727                                               1.22
# 1728                                               1.39
# 1729                                               1.28
#
#       proporcion local cambios alineacion delantero en general  \
# 0                                                  1.22
# 1                                                  1.11
# 2                                                  1.33
# 3                                                  1.11
# 4                                                  0.89
# ...                                                 ...
# 1725                                               0.89
# 1726                                               1.03
# 1727                                               1.08
# 1728                                               1.27
# 1729                                               1.49
#
#       proporcion visitante cambios alineacion delantero en sitio  \
# 0                                                  0.50
# 1                                                  1.50
# 2                                                  1.25
# 3                                                  2.00
# 4                                                  1.50
# ...                                                 ...
# 1725                                               0.78
# 1726                                               1.06
# 1727                                               0.50
# 1728                                               1.22
# 1729                                               0.94
#
#       proporcion visitante cambios alineacion delantero en general  \
# 0                                                  1.00
# 1                                                  1.56
# 2                                                  1.22
# 3                                                  2.00
# 4                                                  1.33
# ...                                                 ...
# 1725                                               0.76
# 1726                                               1.05
# 1727                                               0.57
# 1728                                               1.30
# 1729                                               0.92
#
#       resultado_local  resultado_visitante  resultado_partido  jornada
# 0                   0                    3                  2       10
# 1                   0                    3                  2       10
# 2                   0                    2                  2       10
# 3                   0                    1                  2       10
# 4                   0                    2                  2       10
# ...               ...                  ...                ...      ...
# 1725                2                    2                  X       38
# 1726                2                    1                  1       38
# 1727                0                    0                  X       38
# 1728                1                    1                  X       38
# 1729                2                    1                  1       38
#
# [1730 rows x 174 columns]

# %%
# Eliminar la columna id_partido
df.drop(['id_partido','jornada','id_indicadores_equipo_prepartido'], axis=1, inplace=True)

# %%
# Separar las características (porcentajes) y la clase a predecir (resultado_partido)
X = df.drop(['resultado_partido','resultado_local','resultado_visitante'], axis=1)

# %%
y_resultado=df['resultado_partido']
y_resultado_local=df['resultado_local']
y_resultado_visitante=df['resultado_visitante']

# %%
# Codificar las etiquetas (resultado_partido)
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y_resultado)

# Convertir las etiquetas a one-hot encoding
y_categorical = to_categorical(y_encoded)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_categorical, test_size=0.2, random_state=42)

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(3, activation='softmax')  # Capa de salida con el número de clases
])

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(X_train, y_train, epochs=50, batch_size=16, validation_split=0.1)
# Out:
# Epoch 1/50
# 78/78 [==============================] - 2s 9ms/step - loss: 4.1350 - accuracy: 0.3767 - val_loss: 1.1029 - val_accuracy: 0.4388
# Epoch 2/50
# 78/78 [==============================] - 0s 3ms/step - loss: 1.6604 - accuracy: 0.3759 - val_loss: 1.0867 - val_accuracy: 0.4245
# Epoch 3/50
# 78/78 [==============================] - 0s 5ms/step - loss: 1.3119 - accuracy: 0.3984 - val_loss: 1.0767 - val_accuracy: 0.4388
# Epoch 4/50
# 78/78 [==============================] - 0s 4ms/step - loss: 1.2339 - accuracy: 0.4080 - val_loss: 1.0313 - val_accuracy: 0.4748
# Epoch 5/50
# 78/78 [==============================] - 0s 5ms/step - loss: 1.1656 - accuracy: 0.4056 - val_loss: 1.0384 - val_accuracy: 0.4820
# Epoch 6/50
# 78/78 [==============================] - 0s 4ms/step - loss: 1.1155 - accuracy: 0.4201 - val_loss: 1.0611 - val_accuracy: 0.4532
# Epoch 7/50
# 78/78 [==============================] - 0s 4ms/step - loss: 1.0735 - accuracy: 0.4643 - val_loss: 1.0314 - val_accuracy: 0.4820
# Epoch 8/50
# 78/78 [==============================] - 0s 5ms/step - loss: 1.1087 - accuracy: 0.4490 - val_loss: 1.0675 - val_accuracy: 0.4604
# Epoch 9/50
# 78/78 [==============================] - 0s 4ms/step - loss: 1.0638 - accuracy: 0.4602 - val_loss: 1.0363 - val_accuracy: 0.4820
# Epoch 10/50
# 78/78 [==============================] - 0s 4ms/step - loss: 1.0729 - accuracy: 0.4667 - val_loss: 1.0706 - val_accuracy: 0.4460
# Epoch 11/50
# 78/78 [==============================] - 0s 5ms/step - loss: 1.0348 - accuracy: 0.4900 - val_loss: 1.0533 - val_accuracy: 0.4676
# Epoch 12/50
# 78/78 [==============================] - 0s 5ms/step - loss: 1.0597 - accuracy: 0.4586 - val_loss: 1.0496 - val_accuracy: 0.4532
# Epoch 13/50
# 78/78 [==============================] - 0s 4ms/step - loss: 1.0323 - accuracy: 0.4843 - val_loss: 1.0408 - val_accuracy: 0.4748
# Epoch 14/50
# 78/78 [==============================] - 0s 5ms/step - loss: 1.0392 - accuracy: 0.4747 - val_loss: 1.0309 - val_accuracy: 0.4820
# Epoch 15/50
# 78/78 [==============================] - 0s 5ms/step - loss: 1.0330 - accuracy: 0.4715 - val_loss: 1.0677 - val_accuracy: 0.4245
# Epoch 16/50
# 78/78 [==============================] - 0s 3ms/step - loss: 1.0313 - accuracy: 0.4811 - val_loss: 1.0434 - val_accuracy: 0.4676
# Epoch 17/50
# 78/78 [==============================] - 0s 3ms/step - loss: 1.0452 - accuracy: 0.4859 - val_loss: 1.0532 - val_accuracy: 0.4388
# Epoch 18/50
# 78/78 [==============================] - 0s 3ms/step - loss: 1.0328 - accuracy: 0.4739 - val_loss: 1.0475 - val_accuracy: 0.4460
# Epoch 19/50
# 78/78 [==============================] - 0s 3ms/step - loss: 1.0290 - accuracy: 0.4811 - val_loss: 1.0471 - val_accuracy: 0.4676
# Epoch 20/50
# 78/78 [==============================] - 0s 3ms/step - loss: 1.0259 - accuracy: 0.4827 - val_loss: 1.0423 - val_accuracy: 0.4532
# Epoch 21/50
# 78/78 [==============================] - 0s 3ms/step - loss: 1.0265 - accuracy: 0.4819 - val_loss: 1.0493 - val_accuracy: 0.4676
# Epoch 22/50
# 78/78 [==============================] - 0s 3ms/step - loss: 1.0292 - accuracy: 0.4996 - val_loss: 1.0435 - val_accuracy: 0.4748
# Epoch 23/50
# 78/78 [==============================] - 0s 3ms/step - loss: 1.0197 - accuracy: 0.5044 - val_loss: 1.0456 - val_accuracy: 0.4388
# Epoch 24/50
# 78/78 [==============================] - 0s 3ms/step - loss: 1.0203 - accuracy: 0.5108 - val_loss: 1.0535 - val_accuracy: 0.4676
# Epoch 25/50
# 78/78 [==============================] - 0s 3ms/step - loss: 1.0258 - accuracy: 0.4900 - val_loss: 1.0481 - val_accuracy: 0.4460
# Epoch 26/50
# 78/78 [==============================] - 0s 3ms/step - loss: 1.0135 - accuracy: 0.5036 - val_loss: 1.0498 - val_accuracy: 0.4388
# Epoch 27/50
# 78/78 [==============================] - 0s 3ms/step - loss: 1.0157 - accuracy: 0.4980 - val_loss: 1.0465 - val_accuracy: 0.4460
# Epoch 28/50
# 78/78 [==============================] - 0s 3ms/step - loss: 1.0098 - accuracy: 0.5076 - val_loss: 1.0632 - val_accuracy: 0.4748
# Epoch 29/50
# 78/78 [==============================] - 0s 3ms/step - loss: 1.0153 - accuracy: 0.5173 - val_loss: 1.0421 - val_accuracy: 0.4317
# Epoch 30/50
# 78/78 [==============================] - 0s 3ms/step - loss: 1.0245 - accuracy: 0.4867 - val_loss: 1.0323 - val_accuracy: 0.4820
# Epoch 31/50
# 78/78 [==============================] - 0s 3ms/step - loss: 1.0099 - accuracy: 0.4988 - val_loss: 1.0713 - val_accuracy: 0.4460
# Epoch 32/50
# 78/78 [==============================] - 0s 3ms/step - loss: 1.0058 - accuracy: 0.4988 - val_loss: 1.0540 - val_accuracy: 0.4460
# Epoch 33/50
# 78/78 [==============================] - 0s 3ms/step - loss: 1.0092 - accuracy: 0.5028 - val_loss: 1.0504 - val_accuracy: 0.4748
# Epoch 34/50
# 78/78 [==============================] - 0s 3ms/step - loss: 1.0105 - accuracy: 0.5181 - val_loss: 1.0704 - val_accuracy: 0.4460
# Epoch 35/50
# 78/78 [==============================] - 0s 3ms/step - loss: 1.0115 - accuracy: 0.4948 - val_loss: 1.0404 - val_accuracy: 0.4604
# Epoch 36/50
# 78/78 [==============================] - 0s 5ms/step - loss: 1.0010 - accuracy: 0.5076 - val_loss: 1.0362 - val_accuracy: 0.4820
# Epoch 37/50
# 78/78 [==============================] - 0s 3ms/step - loss: 1.0020 - accuracy: 0.5052 - val_loss: 1.0433 - val_accuracy: 0.4532
# Epoch 38/50
# 78/78 [==============================] - 0s 3ms/step - loss: 0.9966 - accuracy: 0.5052 - val_loss: 1.0455 - val_accuracy: 0.4460
# Epoch 39/50
# 78/78 [==============================] - 0s 5ms/step - loss: 1.0039 - accuracy: 0.5076 - val_loss: 1.0599 - val_accuracy: 0.4820
# Epoch 40/50
# 78/78 [==============================] - 0s 3ms/step - loss: 0.9906 - accuracy: 0.5116 - val_loss: 1.0512 - val_accuracy: 0.4460
# Epoch 41/50
# 78/78 [==============================] - 0s 3ms/step - loss: 1.0020 - accuracy: 0.5100 - val_loss: 1.0647 - val_accuracy: 0.4388
# Epoch 42/50
# 78/78 [==============================] - 0s 3ms/step - loss: 0.9957 - accuracy: 0.5277 - val_loss: 1.0416 - val_accuracy: 0.4532
# Epoch 43/50
# 78/78 [==============================] - 0s 3ms/step - loss: 0.9924 - accuracy: 0.5245 - val_loss: 1.0620 - val_accuracy: 0.4748
# Epoch 44/50
# 78/78 [==============================] - 0s 3ms/step - loss: 0.9974 - accuracy: 0.5197 - val_loss: 1.0493 - val_accuracy: 0.4604
# Epoch 45/50
# 78/78 [==============================] - 0s 3ms/step - loss: 0.9972 - accuracy: 0.5036 - val_loss: 1.0426 - val_accuracy: 0.4460
# Epoch 46/50
# 78/78 [==============================] - 0s 3ms/step - loss: 1.0060 - accuracy: 0.5028 - val_loss: 1.0362 - val_accuracy: 0.4676
# Epoch 47/50
# 78/78 [==============================] - 0s 3ms/step - loss: 0.9966 - accuracy: 0.5269 - val_loss: 1.0635 - val_accuracy: 0.4460
# Epoch 48/50
# 78/78 [==============================] - 0s 3ms/step - loss: 1.0017 - accuracy: 0.5165 - val_loss: 1.0560 - val_accuracy: 0.4245
# Epoch 49/50
# 78/78 [==============================] - 0s 3ms/step - loss: 0.9845 - accuracy: 0.5181 - val_loss: 1.0642 - val_accuracy: 0.4460
# Epoch 50/50
# 78/78 [==============================] - 0s 3ms/step - loss: 0.9772 - accuracy: 0.5221 - val_loss: 1.0617 - val_accuracy: 0.4604

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Pérdida en el conjunto de prueba: {loss:.4f}")
print(f"Precisión en el conjunto de prueba: {accuracy:.4f}")
# Out:
# 11/11 [==============================] - 0s 2ms/step - loss: 0.9846 - accuracy: 0.5462
# Pérdida en el conjunto de prueba: 0.9846
# Precisión en el conjunto de prueba: 0.5462

# %%
# Predecir las probabilidades de las clases en el conjunto de prueba
y_pred_proba = model.predict(X_test)

# Decodificar las etiquetas predichas y reales
y_test_decoded = label_encoder.inverse_transform(np.argmax(y_test, axis=1))
y_pred_decoded = label_encoder.inverse_transform(np.argmax(y_pred_proba, axis=1))

# Mostrar las probabilidades para cada clase junto con la clase real
for i, (probs, true_class, pred_class) in enumerate(zip(y_pred_proba, y_test_decoded, y_pred_decoded)):
    print(f"Partido {i+1}:")
    print(f"  Clase real: {true_class}")
    print(f"  Clase predicha: {pred_class}")
    for class_name, prob in zip(label_encoder.classes_, probs):
        print(f"  Probabilidad de {class_name}: {prob:.4f}")
# Out:
# 11/11 [==============================] - 0s 2ms/step
# Partido 1:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.7075
#   Probabilidad de 2: 0.1187
#   Probabilidad de X: 0.1738
# Partido 2:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.5327
#   Probabilidad de 2: 0.2347
#   Probabilidad de X: 0.2326
# Partido 3:
#   Clase real: 1
#   Clase predicha: 2
#   Probabilidad de 1: 0.3577
#   Probabilidad de 2: 0.4075
#   Probabilidad de X: 0.2349
# Partido 4:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.4892
#   Probabilidad de 2: 0.2713
#   Probabilidad de X: 0.2395
# Partido 5:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.4043
#   Probabilidad de 2: 0.3433
#   Probabilidad de X: 0.2524
# Partido 6:
#   Clase real: X
#   Clase predicha: 2
#   Probabilidad de 1: 0.3374
#   Probabilidad de 2: 0.4228
#   Probabilidad de X: 0.2398
# Partido 7:
#   Clase real: 1
#   Clase predicha: 2
#   Probabilidad de 1: 0.3224
#   Probabilidad de 2: 0.3965
#   Probabilidad de X: 0.2812
# Partido 8:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.6081
#   Probabilidad de 2: 0.1825
#   Probabilidad de X: 0.2094
# Partido 9:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.5085
#   Probabilidad de 2: 0.2541
#   Probabilidad de X: 0.2374
# Partido 10:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.7309
#   Probabilidad de 2: 0.1078
#   Probabilidad de X: 0.1613
# Partido 11:
#   Clase real: 1
#   Clase predicha: 2
#   Probabilidad de 1: 0.3757
#   Probabilidad de 2: 0.3847
#   Probabilidad de X: 0.2396
# Partido 12:
#   Clase real: 2
#   Clase predicha: 2
#   Probabilidad de 1: 0.2875
#   Probabilidad de 2: 0.4516
#   Probabilidad de X: 0.2608
# Partido 13:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.4408
#   Probabilidad de 2: 0.3111
#   Probabilidad de X: 0.2482
# Partido 14:
#   Clase real: 1
#   Clase predicha: 2
#   Probabilidad de 1: 0.1769
#   Probabilidad de 2: 0.6058
#   Probabilidad de X: 0.2174
# Partido 15:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.5423
#   Probabilidad de 2: 0.2300
#   Probabilidad de X: 0.2277
# Partido 16:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.4985
#   Probabilidad de 2: 0.2686
#   Probabilidad de X: 0.2329
# Partido 17:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.5867
#   Probabilidad de 2: 0.1971
#   Probabilidad de X: 0.2161
# Partido 18:
#   Clase real: 1
#   Clase predicha: 2
#   Probabilidad de 1: 0.3692
#   Probabilidad de 2: 0.3786
#   Probabilidad de X: 0.2522
# Partido 19:
#   Clase real: X
#   Clase predicha: 2
#   Probabilidad de 1: 0.3641
#   Probabilidad de 2: 0.3834
#   Probabilidad de X: 0.2525
# Partido 20:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.4362
#   Probabilidad de 2: 0.3089
#   Probabilidad de X: 0.2549
# Partido 21:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.7068
#   Probabilidad de 2: 0.1188
#   Probabilidad de X: 0.1744
# Partido 22:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.8964
#   Probabilidad de 2: 0.0222
#   Probabilidad de X: 0.0814
# Partido 23:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.4582
#   Probabilidad de 2: 0.2967
#   Probabilidad de X: 0.2451
# Partido 24:
#   Clase real: 2
#   Clase predicha: 2
#   Probabilidad de 1: 0.1447
#   Probabilidad de 2: 0.5195
#   Probabilidad de X: 0.3358
# Partido 25:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.4493
#   Probabilidad de 2: 0.3039
#   Probabilidad de X: 0.2468
# Partido 26:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.4806
#   Probabilidad de 2: 0.2790
#   Probabilidad de X: 0.2404
# Partido 27:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.5245
#   Probabilidad de 2: 0.2439
#   Probabilidad de X: 0.2316
# Partido 28:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.7015
#   Probabilidad de 2: 0.1213
#   Probabilidad de X: 0.1772
# Partido 29:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.6254
#   Probabilidad de 2: 0.1688
#   Probabilidad de X: 0.2058
# Partido 30:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.6518
#   Probabilidad de 2: 0.1523
#   Probabilidad de X: 0.1958
# Partido 31:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.4263
#   Probabilidad de 2: 0.3235
#   Probabilidad de X: 0.2502
# Partido 32:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.5198
#   Probabilidad de 2: 0.2459
#   Probabilidad de X: 0.2344
# Partido 33:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.4768
#   Probabilidad de 2: 0.2809
#   Probabilidad de X: 0.2423
# Partido 34:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.4803
#   Probabilidad de 2: 0.2785
#   Probabilidad de X: 0.2412
# Partido 35:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.4477
#   Probabilidad de 2: 0.3055
#   Probabilidad de X: 0.2468
# Partido 36:
#   Clase real: X
#   Clase predicha: 2
#   Probabilidad de 1: 0.1838
#   Probabilidad de 2: 0.5612
#   Probabilidad de X: 0.2550
# Partido 37:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.4970
#   Probabilidad de 2: 0.2640
#   Probabilidad de X: 0.2391
# Partido 38:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.6227
#   Probabilidad de 2: 0.1726
#   Probabilidad de X: 0.2047
# Partido 39:
#   Clase real: 2
#   Clase predicha: 2
#   Probabilidad de 1: 0.1763
#   Probabilidad de 2: 0.6056
#   Probabilidad de X: 0.2181
# Partido 40:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.4960
#   Probabilidad de 2: 0.2652
#   Probabilidad de X: 0.2388
# Partido 41:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.7568
#   Probabilidad de 2: 0.0993
#   Probabilidad de X: 0.1439
# Partido 42:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.4437
#   Probabilidad de 2: 0.3095
#   Probabilidad de X: 0.2468
# Partido 43:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.4799
#   Probabilidad de 2: 0.2787
#   Probabilidad de X: 0.2415
# Partido 44:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.6372
#   Probabilidad de 2: 0.1620
#   Probabilidad de X: 0.2008
# Partido 45:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.5139
#   Probabilidad de 2: 0.2518
#   Probabilidad de X: 0.2343
# Partido 46:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.5460
#   Probabilidad de 2: 0.2262
#   Probabilidad de X: 0.2278
# Partido 47:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.5535
#   Probabilidad de 2: 0.2204
#   Probabilidad de X: 0.2261
# Partido 48:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.4341
#   Probabilidad de 2: 0.3168
#   Probabilidad de X: 0.2491
# Partido 49:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.5154
#   Probabilidad de 2: 0.2489
#   Probabilidad de X: 0.2357
# Partido 50:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.5609
#   Probabilidad de 2: 0.2168
#   Probabilidad de X: 0.2223
# Partido 51:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.6746
#   Probabilidad de 2: 0.1376
#   Probabilidad de X: 0.1878
# Partido 52:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.5129
#   Probabilidad de 2: 0.2518
#   Probabilidad de X: 0.2353
# Partido 53:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.5496
#   Probabilidad de 2: 0.2304
#   Probabilidad de X: 0.2199
# Partido 54:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.5100
#   Probabilidad de 2: 0.2532
#   Probabilidad de X: 0.2368
# Partido 55:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.5557
#   Probabilidad de 2: 0.2194
#   Probabilidad de X: 0.2250
# Partido 56:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.5043
#   Probabilidad de 2: 0.2594
#   Probabilidad de X: 0.2363
# Partido 57:
#   Clase real: X
#   Clase predicha: 2
#   Probabilidad de 1: 0.1163
#   Probabilidad de 2: 0.6335
#   Probabilidad de X: 0.2502
# Partido 58:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.5196
#   Probabilidad de 2: 0.2478
#   Probabilidad de X: 0.2326
# Partido 59:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.5777
#   Probabilidad de 2: 0.2029
#   Probabilidad de X: 0.2195
# Partido 60:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.5186
#   Probabilidad de 2: 0.2472
#   Probabilidad de X: 0.2342
# Partido 61:
#   Clase real: 2
#   Clase predicha: 2
#   Probabilidad de 1: 0.2256
#   Probabilidad de 2: 0.5277
#   Probabilidad de X: 0.2467
# Partido 62:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.5831
#   Probabilidad de 2: 0.1991
#   Probabilidad de X: 0.2178
# Partido 63:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.4640
#   Probabilidad de 2: 0.2918
#   Probabilidad de X: 0.2442
# Partido 64:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.4542
#   Probabilidad de 2: 0.2998
#   Probabilidad de X: 0.2460
# Partido 65:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.4043
#   Probabilidad de 2: 0.3433
#   Probabilidad de X: 0.2524
# Partido 66:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.6557
#   Probabilidad de 2: 0.1490
#   Probabilidad de X: 0.1953
# Partido 67:
#   Clase real: 2
#   Clase predicha: 2
#   Probabilidad de 1: 0.3680
#   Probabilidad de 2: 0.3848
#   Probabilidad de X: 0.2472
# Partido 68:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.5293
#   Probabilidad de 2: 0.2394
#   Probabilidad de X: 0.2314
# Partido 69:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.4779
#   Probabilidad de 2: 0.2813
#   Probabilidad de X: 0.2408
# Partido 70:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.4621
#   Probabilidad de 2: 0.2933
#   Probabilidad de X: 0.2446
# Partido 71:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.4656
#   Probabilidad de 2: 0.2910
#   Probabilidad de X: 0.2434
# Partido 72:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.4872
#   Probabilidad de 2: 0.2727
#   Probabilidad de X: 0.2402
# Partido 73:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.4996
#   Probabilidad de 2: 0.2629
#   Probabilidad de X: 0.2375
# Partido 74:
#   Clase real: X
#   Clase predicha: 2
#   Probabilidad de 1: 0.3363
#   Probabilidad de 2: 0.4288
#   Probabilidad de X: 0.2350
# Partido 75:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.4791
#   Probabilidad de 2: 0.2792
#   Probabilidad de X: 0.2418
# Partido 76:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.4380
#   Probabilidad de 2: 0.3135
#   Probabilidad de X: 0.2486
# Partido 77:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.6357
#   Probabilidad de 2: 0.1632
#   Probabilidad de X: 0.2012
# Partido 78:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.3830
#   Probabilidad de 2: 0.3559
#   Probabilidad de X: 0.2611
# Partido 79:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.7617
#   Probabilidad de 2: 0.0848
#   Probabilidad de X: 0.1535
# Partido 80:
#   Clase real: 2
#   Clase predicha: 2
#   Probabilidad de 1: 0.3214
#   Probabilidad de 2: 0.4587
#   Probabilidad de X: 0.2199
# Partido 81:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.7104
#   Probabilidad de 2: 0.1168
#   Probabilidad de X: 0.1729
# Partido 82:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.4617
#   Probabilidad de 2: 0.2919
#   Probabilidad de X: 0.2464
# Partido 83:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.4528
#   Probabilidad de 2: 0.3019
#   Probabilidad de X: 0.2453
# Partido 84:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.5331
#   Probabilidad de 2: 0.2387
#   Probabilidad de X: 0.2282
# Partido 85:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.5085
#   Probabilidad de 2: 0.2550
#   Probabilidad de X: 0.2365
# Partido 86:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.5715
#   Probabilidad de 2: 0.2071
#   Probabilidad de X: 0.2213
# Partido 87:
#   Clase real: 1
#   Clase predicha: 2
#   Probabilidad de 1: 0.3433
#   Probabilidad de 2: 0.4119
#   Probabilidad de X: 0.2448
# Partido 88:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.5721
#   Probabilidad de 2: 0.2060
#   Probabilidad de X: 0.2219
# Partido 89:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.6588
#   Probabilidad de 2: 0.1541
#   Probabilidad de X: 0.1871
# Partido 90:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.6408
#   Probabilidad de 2: 0.1580
#   Probabilidad de X: 0.2012
# Partido 91:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.5558
#   Probabilidad de 2: 0.2199
#   Probabilidad de X: 0.2243
# Partido 92:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.5938
#   Probabilidad de 2: 0.1914
#   Probabilidad de X: 0.2148
# Partido 93:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.8022
#   Probabilidad de 2: 0.0635
#   Probabilidad de X: 0.1343
# Partido 94:
#   Clase real: X
#   Clase predicha: 2
#   Probabilidad de 1: 0.3009
#   Probabilidad de 2: 0.4749
#   Probabilidad de X: 0.2243
# Partido 95:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.4043
#   Probabilidad de 2: 0.3433
#   Probabilidad de X: 0.2524
# Partido 96:
#   Clase real: 1
#   Clase predicha: 2
#   Probabilidad de 1: 0.0595
#   Probabilidad de 2: 0.7071
#   Probabilidad de X: 0.2334
# Partido 97:
#   Clase real: 2
#   Clase predicha: 2
#   Probabilidad de 1: 0.2305
#   Probabilidad de 2: 0.5380
#   Probabilidad de X: 0.2316
# Partido 98:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.6700
#   Probabilidad de 2: 0.1403
#   Probabilidad de X: 0.1897
# Partido 99:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.6393
#   Probabilidad de 2: 0.1591
#   Probabilidad de X: 0.2016
# Partido 100:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.6002
#   Probabilidad de 2: 0.1878
#   Probabilidad de X: 0.2120
# Partido 101:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.4741
#   Probabilidad de 2: 0.2847
#   Probabilidad de X: 0.2412
# Partido 102:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.6380
#   Probabilidad de 2: 0.1612
#   Probabilidad de X: 0.2008
# Partido 103:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.5394
#   Probabilidad de 2: 0.2305
#   Probabilidad de X: 0.2301
# Partido 104:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.7622
#   Probabilidad de 2: 0.0844
#   Probabilidad de X: 0.1534
# Partido 105:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.3858
#   Probabilidad de 2: 0.3646
#   Probabilidad de X: 0.2496
# Partido 106:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.4573
#   Probabilidad de 2: 0.2972
#   Probabilidad de X: 0.2455
# Partido 107:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.6377
#   Probabilidad de 2: 0.1623
#   Probabilidad de X: 0.2000
# Partido 108:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.6682
#   Probabilidad de 2: 0.1397
#   Probabilidad de X: 0.1921
# Partido 109:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.6527
#   Probabilidad de 2: 0.1530
#   Probabilidad de X: 0.1943
# Partido 110:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.4320
#   Probabilidad de 2: 0.3183
#   Probabilidad de X: 0.2497
# Partido 111:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.5053
#   Probabilidad de 2: 0.2575
#   Probabilidad de X: 0.2372
# Partido 112:
#   Clase real: 2
#   Clase predicha: 2
#   Probabilidad de 1: 0.2555
#   Probabilidad de 2: 0.4837
#   Probabilidad de X: 0.2607
# Partido 113:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.5018
#   Probabilidad de 2: 0.2611
#   Probabilidad de X: 0.2371
# Partido 114:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.7774
#   Probabilidad de 2: 0.0808
#   Probabilidad de X: 0.1418
# Partido 115:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.7449
#   Probabilidad de 2: 0.0957
#   Probabilidad de X: 0.1595
# Partido 116:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.5314
#   Probabilidad de 2: 0.2379
#   Probabilidad de X: 0.2307
# Partido 117:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.5380
#   Probabilidad de 2: 0.2406
#   Probabilidad de X: 0.2214
# Partido 118:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.4862
#   Probabilidad de 2: 0.2738
#   Probabilidad de X: 0.2401
# Partido 119:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.6217
#   Probabilidad de 2: 0.1734
#   Probabilidad de X: 0.2049
# Partido 120:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.6819
#   Probabilidad de 2: 0.1298
#   Probabilidad de X: 0.1883
# Partido 121:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.5237
#   Probabilidad de 2: 0.2438
#   Probabilidad de X: 0.2326
# Partido 122:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.4045
#   Probabilidad de 2: 0.3432
#   Probabilidad de X: 0.2523
# Partido 123:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.4586
#   Probabilidad de 2: 0.2964
#   Probabilidad de X: 0.2451
# Partido 124:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.4583
#   Probabilidad de 2: 0.2987
#   Probabilidad de X: 0.2431
# Partido 125:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.5969
#   Probabilidad de 2: 0.1912
#   Probabilidad de X: 0.2119
# Partido 126:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.6527
#   Probabilidad de 2: 0.1503
#   Probabilidad de X: 0.1970
# Partido 127:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.3820
#   Probabilidad de 2: 0.3640
#   Probabilidad de X: 0.2541
# Partido 128:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.7831
#   Probabilidad de 2: 0.0734
#   Probabilidad de X: 0.1435
# Partido 129:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.4890
#   Probabilidad de 2: 0.2712
#   Probabilidad de X: 0.2399
# Partido 130:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.4540
#   Probabilidad de 2: 0.3001
#   Probabilidad de X: 0.2460
# Partido 131:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.5858
#   Probabilidad de 2: 0.1971
#   Probabilidad de X: 0.2171
# Partido 132:
#   Clase real: X
#   Clase predicha: 2
#   Probabilidad de 1: 0.3246
#   Probabilidad de 2: 0.3872
#   Probabilidad de X: 0.2882
# Partido 133:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.4436
#   Probabilidad de 2: 0.3080
#   Probabilidad de X: 0.2484
# Partido 134:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.6366
#   Probabilidad de 2: 0.1606
#   Probabilidad de X: 0.2027
# Partido 135:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.6459
#   Probabilidad de 2: 0.1579
#   Probabilidad de X: 0.1962
# Partido 136:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.4285
#   Probabilidad de 2: 0.3215
#   Probabilidad de X: 0.2499
# Partido 137:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.4998
#   Probabilidad de 2: 0.2624
#   Probabilidad de X: 0.2379
# Partido 138:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.4148
#   Probabilidad de 2: 0.3332
#   Probabilidad de X: 0.2520
# Partido 139:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.7393
#   Probabilidad de 2: 0.0986
#   Probabilidad de X: 0.1621
# Partido 140:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.4591
#   Probabilidad de 2: 0.2959
#   Probabilidad de X: 0.2451
# Partido 141:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.5784
#   Probabilidad de 2: 0.2025
#   Probabilidad de X: 0.2191
# Partido 142:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.4251
#   Probabilidad de 2: 0.3261
#   Probabilidad de X: 0.2488
# Partido 143:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.5414
#   Probabilidad de 2: 0.2309
#   Probabilidad de X: 0.2277
# Partido 144:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.6066
#   Probabilidad de 2: 0.1826
#   Probabilidad de X: 0.2107
# Partido 145:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.9162
#   Probabilidad de 2: 0.0164
#   Probabilidad de X: 0.0673
# Partido 146:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.5837
#   Probabilidad de 2: 0.2013
#   Probabilidad de X: 0.2150
# Partido 147:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.4190
#   Probabilidad de 2: 0.3302
#   Probabilidad de X: 0.2508
# Partido 148:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.8081
#   Probabilidad de 2: 0.0604
#   Probabilidad de X: 0.1315
# Partido 149:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.6204
#   Probabilidad de 2: 0.1751
#   Probabilidad de X: 0.2045
# Partido 150:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.4969
#   Probabilidad de 2: 0.2645
#   Probabilidad de X: 0.2385
# Partido 151:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.5688
#   Probabilidad de 2: 0.2101
#   Probabilidad de X: 0.2211
# Partido 152:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.4641
#   Probabilidad de 2: 0.2914
#   Probabilidad de X: 0.2444
# Partido 153:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.7191
#   Probabilidad de 2: 0.1149
#   Probabilidad de X: 0.1660
# Partido 154:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.4879
#   Probabilidad de 2: 0.2729
#   Probabilidad de X: 0.2392
# Partido 155:
#   Clase real: 2
#   Clase predicha: 2
#   Probabilidad de 1: 0.1265
#   Probabilidad de 2: 0.5354
#   Probabilidad de X: 0.3382
# Partido 156:
#   Clase real: 2
#   Clase predicha: 2
#   Probabilidad de 1: 0.2779
#   Probabilidad de 2: 0.4610
#   Probabilidad de X: 0.2611
# Partido 157:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.8373
#   Probabilidad de 2: 0.0469
#   Probabilidad de X: 0.1158
# Partido 158:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.4315
#   Probabilidad de 2: 0.3189
#   Probabilidad de X: 0.2497
# Partido 159:
#   Clase real: X
#   Clase predicha: 2
#   Probabilidad de 1: 0.1306
#   Probabilidad de 2: 0.6439
#   Probabilidad de X: 0.2255
# Partido 160:
#   Clase real: 2
#   Clase predicha: 2
#   Probabilidad de 1: 0.1177
#   Probabilidad de 2: 0.6583
#   Probabilidad de X: 0.2240
# Partido 161:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.4476
#   Probabilidad de 2: 0.3053
#   Probabilidad de X: 0.2471
# Partido 162:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.4468
#   Probabilidad de 2: 0.3074
#   Probabilidad de X: 0.2458
# Partido 163:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.6587
#   Probabilidad de 2: 0.1535
#   Probabilidad de X: 0.1878
# Partido 164:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.4942
#   Probabilidad de 2: 0.2664
#   Probabilidad de X: 0.2395
# Partido 165:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.5465
#   Probabilidad de 2: 0.2265
#   Probabilidad de X: 0.2270
# Partido 166:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.4264
#   Probabilidad de 2: 0.3229
#   Probabilidad de X: 0.2507
# Partido 167:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.6060
#   Probabilidad de 2: 0.1836
#   Probabilidad de X: 0.2104
# Partido 168:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.4057
#   Probabilidad de 2: 0.3410
#   Probabilidad de X: 0.2532
# Partido 169:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.5578
#   Probabilidad de 2: 0.2249
#   Probabilidad de X: 0.2173
# Partido 170:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.4542
#   Probabilidad de 2: 0.2998
#   Probabilidad de X: 0.2460
# Partido 171:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.5165
#   Probabilidad de 2: 0.2498
#   Probabilidad de X: 0.2337
# Partido 172:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.4913
#   Probabilidad de 2: 0.2696
#   Probabilidad de X: 0.2391
# Partido 173:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.6701
#   Probabilidad de 2: 0.1402
#   Probabilidad de X: 0.1897
# Partido 174:
#   Clase real: 2
#   Clase predicha: 2
#   Probabilidad de 1: 0.2417
#   Probabilidad de 2: 0.5318
#   Probabilidad de X: 0.2265
# Partido 175:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.4783
#   Probabilidad de 2: 0.2801
#   Probabilidad de X: 0.2417
# Partido 176:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.5157
#   Probabilidad de 2: 0.2504
#   Probabilidad de X: 0.2339
# Partido 177:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.5259
#   Probabilidad de 2: 0.2429
#   Probabilidad de X: 0.2312
# Partido 178:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.6447
#   Probabilidad de 2: 0.1552
#   Probabilidad de X: 0.2001
# Partido 179:
#   Clase real: 1
#   Clase predicha: 2
#   Probabilidad de 1: 0.3679
#   Probabilidad de 2: 0.3896
#   Probabilidad de X: 0.2426
# Partido 180:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.4860
#   Probabilidad de 2: 0.2754
#   Probabilidad de X: 0.2386
# Partido 181:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.4822
#   Probabilidad de 2: 0.2768
#   Probabilidad de X: 0.2409
# Partido 182:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.5224
#   Probabilidad de 2: 0.2440
#   Probabilidad de X: 0.2336
# Partido 183:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.5610
#   Probabilidad de 2: 0.2183
#   Probabilidad de X: 0.2207
# Partido 184:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.6267
#   Probabilidad de 2: 0.1708
#   Probabilidad de X: 0.2025
# Partido 185:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.5013
#   Probabilidad de 2: 0.2617
#   Probabilidad de X: 0.2370
# Partido 186:
#   Clase real: X
#   Clase predicha: 2
#   Probabilidad de 1: 0.2588
#   Probabilidad de 2: 0.4892
#   Probabilidad de X: 0.2521
# Partido 187:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.5150
#   Probabilidad de 2: 0.2536
#   Probabilidad de X: 0.2314
# Partido 188:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.4739
#   Probabilidad de 2: 0.2837
#   Probabilidad de X: 0.2425
# Partido 189:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.4043
#   Probabilidad de 2: 0.3433
#   Probabilidad de X: 0.2524
# Partido 190:
#   Clase real: 2
#   Clase predicha: 2
#   Probabilidad de 1: 0.2704
#   Probabilidad de 2: 0.4478
#   Probabilidad de X: 0.2818
# Partido 191:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.5731
#   Probabilidad de 2: 0.2100
#   Probabilidad de X: 0.2169
# Partido 192:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.5524
#   Probabilidad de 2: 0.2230
#   Probabilidad de X: 0.2246
# Partido 193:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.3782
#   Probabilidad de 2: 0.3589
#   Probabilidad de X: 0.2629
# Partido 194:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.4817
#   Probabilidad de 2: 0.2777
#   Probabilidad de X: 0.2406
# Partido 195:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.7073
#   Probabilidad de 2: 0.1225
#   Probabilidad de X: 0.1702
# Partido 196:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.5185
#   Probabilidad de 2: 0.2484
#   Probabilidad de X: 0.2331
# Partido 197:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.5182
#   Probabilidad de 2: 0.2486
#   Probabilidad de X: 0.2331
# Partido 198:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.6189
#   Probabilidad de 2: 0.1744
#   Probabilidad de X: 0.2067
# Partido 199:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.4668
#   Probabilidad de 2: 0.2891
#   Probabilidad de X: 0.2441
# Partido 200:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.5198
#   Probabilidad de 2: 0.2470
#   Probabilidad de X: 0.2332
# Partido 201:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.5208
#   Probabilidad de 2: 0.2470
#   Probabilidad de X: 0.2322
# Partido 202:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.5580
#   Probabilidad de 2: 0.2193
#   Probabilidad de X: 0.2227
# Partido 203:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.4560
#   Probabilidad de 2: 0.2980
#   Probabilidad de X: 0.2461
# Partido 204:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.5464
#   Probabilidad de 2: 0.2268
#   Probabilidad de X: 0.2269
# Partido 205:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.4326
#   Probabilidad de 2: 0.3185
#   Probabilidad de X: 0.2489
# Partido 206:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.5199
#   Probabilidad de 2: 0.2487
#   Probabilidad de X: 0.2314
# Partido 207:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.4866
#   Probabilidad de 2: 0.2742
#   Probabilidad de X: 0.2392
# Partido 208:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.4961
#   Probabilidad de 2: 0.2655
#   Probabilidad de X: 0.2385
# Partido 209:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.5666
#   Probabilidad de 2: 0.2138
#   Probabilidad de X: 0.2196
# Partido 210:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.4813
#   Probabilidad de 2: 0.2779
#   Probabilidad de X: 0.2408
# Partido 211:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.6769
#   Probabilidad de 2: 0.1355
#   Probabilidad de X: 0.1876
# Partido 212:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.8199
#   Probabilidad de 2: 0.0557
#   Probabilidad de X: 0.1244
# Partido 213:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.4228
#   Probabilidad de 2: 0.3256
#   Probabilidad de X: 0.2516
# Partido 214:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.6851
#   Probabilidad de 2: 0.1304
#   Probabilidad de X: 0.1845
# Partido 215:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.4587
#   Probabilidad de 2: 0.2959
#   Probabilidad de X: 0.2455
# Partido 216:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.5574
#   Probabilidad de 2: 0.2178
#   Probabilidad de X: 0.2248
# Partido 217:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.6911
#   Probabilidad de 2: 0.1252
#   Probabilidad de X: 0.1837
# Partido 218:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.5134
#   Probabilidad de 2: 0.2525
#   Probabilidad de X: 0.2341
# Partido 219:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.5706
#   Probabilidad de 2: 0.2099
#   Probabilidad de X: 0.2195
# Partido 220:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.4978
#   Probabilidad de 2: 0.2643
#   Probabilidad de X: 0.2380
# Partido 221:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.4588
#   Probabilidad de 2: 0.2956
#   Probabilidad de X: 0.2456
# Partido 222:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.7559
#   Probabilidad de 2: 0.0888
#   Probabilidad de X: 0.1553
# Partido 223:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.8066
#   Probabilidad de 2: 0.0629
#   Probabilidad de X: 0.1305
# Partido 224:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.7530
#   Probabilidad de 2: 0.0886
#   Probabilidad de X: 0.1584
# Partido 225:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.8447
#   Probabilidad de 2: 0.0459
#   Probabilidad de X: 0.1094
# Partido 226:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.5164
#   Probabilidad de 2: 0.2499
#   Probabilidad de X: 0.2337
# Partido 227:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.5563
#   Probabilidad de 2: 0.2192
#   Probabilidad de X: 0.2244
# Partido 228:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.7048
#   Probabilidad de 2: 0.1245
#   Probabilidad de X: 0.1707
# Partido 229:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.5237
#   Probabilidad de 2: 0.2440
#   Probabilidad de X: 0.2323
# Partido 230:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.6417
#   Probabilidad de 2: 0.1585
#   Probabilidad de X: 0.1998
# Partido 231:
#   Clase real: X
#   Clase predicha: 2
#   Probabilidad de 1: 0.3635
#   Probabilidad de 2: 0.3898
#   Probabilidad de X: 0.2468
# Partido 232:
#   Clase real: 2
#   Clase predicha: 2
#   Probabilidad de 1: 0.1568
#   Probabilidad de 2: 0.5605
#   Probabilidad de X: 0.2826
# Partido 233:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.6274
#   Probabilidad de 2: 0.1687
#   Probabilidad de X: 0.2038
# Partido 234:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.6235
#   Probabilidad de 2: 0.1698
#   Probabilidad de X: 0.2067
# Partido 235:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.4503
#   Probabilidad de 2: 0.3031
#   Probabilidad de X: 0.2466
# Partido 236:
#   Clase real: 2
#   Clase predicha: 2
#   Probabilidad de 1: 0.0659
#   Probabilidad de 2: 0.6502
#   Probabilidad de X: 0.2839
# Partido 237:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.5196
#   Probabilidad de 2: 0.2469
#   Probabilidad de X: 0.2334
# Partido 238:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.4895
#   Probabilidad de 2: 0.2706
#   Probabilidad de X: 0.2399
# Partido 239:
#   Clase real: X
#   Clase predicha: 2
#   Probabilidad de 1: 0.2361
#   Probabilidad de 2: 0.5364
#   Probabilidad de X: 0.2274
# Partido 240:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.5824
#   Probabilidad de 2: 0.1996
#   Probabilidad de X: 0.2180
# Partido 241:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.5521
#   Probabilidad de 2: 0.2218
#   Probabilidad de X: 0.2261
# Partido 242:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.4443
#   Probabilidad de 2: 0.3081
#   Probabilidad de X: 0.2476
# Partido 243:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.5225
#   Probabilidad de 2: 0.2456
#   Probabilidad de X: 0.2319
# Partido 244:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.4663
#   Probabilidad de 2: 0.2899
#   Probabilidad de X: 0.2438
# Partido 245:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.5263
#   Probabilidad de 2: 0.2411
#   Probabilidad de X: 0.2326
# Partido 246:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.5885
#   Probabilidad de 2: 0.1963
#   Probabilidad de X: 0.2152
# Partido 247:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.3850
#   Probabilidad de 2: 0.3642
#   Probabilidad de X: 0.2508
# Partido 248:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.5297
#   Probabilidad de 2: 0.2399
#   Probabilidad de X: 0.2303
# Partido 249:
#   Clase real: 1
#   Clase predicha: 2
#   Probabilidad de 1: 0.3038
#   Probabilidad de 2: 0.4358
#   Probabilidad de X: 0.2604
# Partido 250:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.3983
#   Probabilidad de 2: 0.3644
#   Probabilidad de X: 0.2373
# Partido 251:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.7951
#   Probabilidad de 2: 0.0684
#   Probabilidad de X: 0.1364
# Partido 252:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.5732
#   Probabilidad de 2: 0.2077
#   Probabilidad de X: 0.2190
# Partido 253:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.5090
#   Probabilidad de 2: 0.2551
#   Probabilidad de X: 0.2359
# Partido 254:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.6050
#   Probabilidad de 2: 0.1823
#   Probabilidad de X: 0.2127
# Partido 255:
#   Clase real: X
#   Clase predicha: 2
#   Probabilidad de 1: 0.3326
#   Probabilidad de 2: 0.4368
#   Probabilidad de X: 0.2306
# Partido 256:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.4597
#   Probabilidad de 2: 0.2963
#   Probabilidad de X: 0.2440
# Partido 257:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.5744
#   Probabilidad de 2: 0.2049
#   Probabilidad de X: 0.2207
# Partido 258:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.4978
#   Probabilidad de 2: 0.2638
#   Probabilidad de X: 0.2385
# Partido 259:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.4211
#   Probabilidad de 2: 0.3275
#   Probabilidad de X: 0.2514
# Partido 260:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.6185
#   Probabilidad de 2: 0.1780
#   Probabilidad de X: 0.2035
# Partido 261:
#   Clase real: 2
#   Clase predicha: 2
#   Probabilidad de 1: 0.1998
#   Probabilidad de 2: 0.5471
#   Probabilidad de X: 0.2531
# Partido 262:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.5647
#   Probabilidad de 2: 0.2135
#   Probabilidad de X: 0.2219
# Partido 263:
#   Clase real: 2
#   Clase predicha: 2
#   Probabilidad de 1: 0.3104
#   Probabilidad de 2: 0.4545
#   Probabilidad de X: 0.2350
# Partido 264:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.5041
#   Probabilidad de 2: 0.2586
#   Probabilidad de X: 0.2373
# Partido 265:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.5363
#   Probabilidad de 2: 0.2341
#   Probabilidad de X: 0.2297
# Partido 266:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.5647
#   Probabilidad de 2: 0.2134
#   Probabilidad de X: 0.2219
# Partido 267:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.6871
#   Probabilidad de 2: 0.1351
#   Probabilidad de X: 0.1778
# Partido 268:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.5701
#   Probabilidad de 2: 0.2092
#   Probabilidad de X: 0.2207
# Partido 269:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.4867
#   Probabilidad de 2: 0.2734
#   Probabilidad de X: 0.2399
# Partido 270:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.5866
#   Probabilidad de 2: 0.1976
#   Probabilidad de X: 0.2159
# Partido 271:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.4841
#   Probabilidad de 2: 0.2748
#   Probabilidad de X: 0.2411
# Partido 272:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.5851
#   Probabilidad de 2: 0.1973
#   Probabilidad de X: 0.2177
# Partido 273:
#   Clase real: 2
#   Clase predicha: 2
#   Probabilidad de 1: 0.1317
#   Probabilidad de 2: 0.5434
#   Probabilidad de X: 0.3249
# Partido 274:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.4938
#   Probabilidad de 2: 0.2667
#   Probabilidad de X: 0.2395
# Partido 275:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.4762
#   Probabilidad de 2: 0.2811
#   Probabilidad de X: 0.2427
# Partido 276:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.7532
#   Probabilidad de 2: 0.1026
#   Probabilidad de X: 0.1443
# Partido 277:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.5192
#   Probabilidad de 2: 0.2472
#   Probabilidad de X: 0.2335
# Partido 278:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.6164
#   Probabilidad de 2: 0.1792
#   Probabilidad de X: 0.2044
# Partido 279:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.4840
#   Probabilidad de 2: 0.2749
#   Probabilidad de X: 0.2410
# Partido 280:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.4844
#   Probabilidad de 2: 0.2749
#   Probabilidad de X: 0.2407
# Partido 281:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.4452
#   Probabilidad de 2: 0.3074
#   Probabilidad de X: 0.2474
# Partido 282:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.6297
#   Probabilidad de 2: 0.1667
#   Probabilidad de X: 0.2035
# Partido 283:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.4001
#   Probabilidad de 2: 0.3557
#   Probabilidad de X: 0.2443
# Partido 284:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.7010
#   Probabilidad de 2: 0.1202
#   Probabilidad de X: 0.1787
# Partido 285:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.7006
#   Probabilidad de 2: 0.1218
#   Probabilidad de X: 0.1775
# Partido 286:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.4236
#   Probabilidad de 2: 0.3258
#   Probabilidad de X: 0.2506
# Partido 287:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.5214
#   Probabilidad de 2: 0.2454
#   Probabilidad de X: 0.2332
# Partido 288:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.5506
#   Probabilidad de 2: 0.2221
#   Probabilidad de X: 0.2273
# Partido 289:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.4938
#   Probabilidad de 2: 0.2667
#   Probabilidad de X: 0.2394
# Partido 290:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.5790
#   Probabilidad de 2: 0.2010
#   Probabilidad de X: 0.2200
# Partido 291:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.4674
#   Probabilidad de 2: 0.2884
#   Probabilidad de X: 0.2442
# Partido 292:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.7093
#   Probabilidad de 2: 0.1149
#   Probabilidad de X: 0.1758
# Partido 293:
#   Clase real: X
#   Clase predicha: 2
#   Probabilidad de 1: 0.1177
#   Probabilidad de 2: 0.5405
#   Probabilidad de X: 0.3418
# Partido 294:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.7119
#   Probabilidad de 2: 0.1143
#   Probabilidad de X: 0.1738
# Partido 295:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.3987
#   Probabilidad de 2: 0.3490
#   Probabilidad de X: 0.2522
# Partido 296:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.5697
#   Probabilidad de 2: 0.2135
#   Probabilidad de X: 0.2168
# Partido 297:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.4751
#   Probabilidad de 2: 0.2827
#   Probabilidad de X: 0.2423
# Partido 298:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.6252
#   Probabilidad de 2: 0.1688
#   Probabilidad de X: 0.2060
# Partido 299:
#   Clase real: 2
#   Clase predicha: 2
#   Probabilidad de 1: 0.3267
#   Probabilidad de 2: 0.4384
#   Probabilidad de X: 0.2349
# Partido 300:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.5154
#   Probabilidad de 2: 0.2507
#   Probabilidad de X: 0.2338
# Partido 301:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.7135
#   Probabilidad de 2: 0.1116
#   Probabilidad de X: 0.1749
# Partido 302:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.4107
#   Probabilidad de 2: 0.3352
#   Probabilidad de X: 0.2541
# Partido 303:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.8634
#   Probabilidad de 2: 0.0369
#   Probabilidad de X: 0.0998
# Partido 304:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.5067
#   Probabilidad de 2: 0.2576
#   Probabilidad de X: 0.2356
# Partido 305:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.4043
#   Probabilidad de 2: 0.3433
#   Probabilidad de X: 0.2524
# Partido 306:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.6179
#   Probabilidad de 2: 0.1747
#   Probabilidad de X: 0.2074
# Partido 307:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.6318
#   Probabilidad de 2: 0.1652
#   Probabilidad de X: 0.2031
# Partido 308:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.4754
#   Probabilidad de 2: 0.2823
#   Probabilidad de X: 0.2423
# Partido 309:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.5215
#   Probabilidad de 2: 0.2450
#   Probabilidad de X: 0.2335
# Partido 310:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.6461
#   Probabilidad de 2: 0.1551
#   Probabilidad de X: 0.1987
# Partido 311:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.6850
#   Probabilidad de 2: 0.1321
#   Probabilidad de X: 0.1830
# Partido 312:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.4743
#   Probabilidad de 2: 0.2841
#   Probabilidad de X: 0.2416
# Partido 313:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.4866
#   Probabilidad de 2: 0.2740
#   Probabilidad de X: 0.2394
# Partido 314:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.7427
#   Probabilidad de 2: 0.0969
#   Probabilidad de X: 0.1604
# Partido 315:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.8496
#   Probabilidad de 2: 0.0425
#   Probabilidad de X: 0.1079
# Partido 316:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.6480
#   Probabilidad de 2: 0.1546
#   Probabilidad de X: 0.1974
# Partido 317:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.3983
#   Probabilidad de 2: 0.3552
#   Probabilidad de X: 0.2465
# Partido 318:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.7761
#   Probabilidad de 2: 0.0808
#   Probabilidad de X: 0.1432
# Partido 319:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.4356
#   Probabilidad de 2: 0.3155
#   Probabilidad de X: 0.2489
# Partido 320:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.5200
#   Probabilidad de 2: 0.2474
#   Probabilidad de X: 0.2325
# Partido 321:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.4686
#   Probabilidad de 2: 0.2881
#   Probabilidad de X: 0.2432
# Partido 322:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.5442
#   Probabilidad de 2: 0.2278
#   Probabilidad de X: 0.2280
# Partido 323:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.4215
#   Probabilidad de 2: 0.3277
#   Probabilidad de X: 0.2509
# Partido 324:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.6151
#   Probabilidad de 2: 0.1772
#   Probabilidad de X: 0.2077
# Partido 325:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.4850
#   Probabilidad de 2: 0.2740
#   Probabilidad de X: 0.2410
# Partido 326:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.6317
#   Probabilidad de 2: 0.1657
#   Probabilidad de X: 0.2026
# Partido 327:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.6465
#   Probabilidad de 2: 0.1548
#   Probabilidad de X: 0.1986
# Partido 328:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.3917
#   Probabilidad de 2: 0.3215
#   Probabilidad de X: 0.2869
# Partido 329:
#   Clase real: 2
#   Clase predicha: 2
#   Probabilidad de 1: 0.2336
#   Probabilidad de 2: 0.5320
#   Probabilidad de X: 0.2345
# Partido 330:
#   Clase real: 2
#   Clase predicha: 2
#   Probabilidad de 1: 0.1745
#   Probabilidad de 2: 0.5009
#   Probabilidad de X: 0.3246
# Partido 331:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.4772
#   Probabilidad de 2: 0.2810
#   Probabilidad de X: 0.2418
# Partido 332:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.4364
#   Probabilidad de 2: 0.3149
#   Probabilidad de X: 0.2488
# Partido 333:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.5634
#   Probabilidad de 2: 0.2133
#   Probabilidad de X: 0.2233
# Partido 334:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.5940
#   Probabilidad de 2: 0.1924
#   Probabilidad de X: 0.2136
# Partido 335:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.4616
#   Probabilidad de 2: 0.2937
#   Probabilidad de X: 0.2447
# Partido 336:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.8426
#   Probabilidad de 2: 0.0437
#   Probabilidad de X: 0.1137
# Partido 337:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.4338
#   Probabilidad de 2: 0.3177
#   Probabilidad de X: 0.2485
# Partido 338:
#   Clase real: 2
#   Clase predicha: 2
#   Probabilidad de 1: 0.2909
#   Probabilidad de 2: 0.4197
#   Probabilidad de X: 0.2894
# Partido 339:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.4043
#   Probabilidad de 2: 0.3433
#   Probabilidad de X: 0.2524
# Partido 340:
#   Clase real: 2
#   Clase predicha: 2
#   Probabilidad de 1: 0.1683
#   Probabilidad de 2: 0.5879
#   Probabilidad de X: 0.2438
# Partido 341:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.5413
#   Probabilidad de 2: 0.2299
#   Probabilidad de X: 0.2288
# Partido 342:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.5687
#   Probabilidad de 2: 0.2103
#   Probabilidad de X: 0.2210
# Partido 343:
#   Clase real: 2
#   Clase predicha: 2
#   Probabilidad de 1: 0.3007
#   Probabilidad de 2: 0.4108
#   Probabilidad de X: 0.2885
# Partido 344:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.4974
#   Probabilidad de 2: 0.2652
#   Probabilidad de X: 0.2374
# Partido 345:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.4994
#   Probabilidad de 2: 0.2631
#   Probabilidad de X: 0.2375
# Partido 346:
#   Clase real: 2
#   Clase predicha: 2
#   Probabilidad de 1: 0.2241
#   Probabilidad de 2: 0.5239
#   Probabilidad de X: 0.2520
