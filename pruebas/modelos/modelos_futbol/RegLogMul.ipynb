# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('indicadoresEquipoHistoricoModelo.csv',sep=",")
df
# Out:
#      id_indicadores_equipo_prepartido  id_partido
# 0                                89.0        98.0  \
# 1                                90.0        96.0
# 2                                91.0        94.0
# 3                                92.0        93.0
# 4                                93.0        97.0
# ..                                ...         ...
# 255                             345.0       341.0
# 256                             346.0       346.0
# 257                             347.0       348.0
# 258                             348.0       342.0
# 259                             349.0       344.0
#
#      porcentaje local ganados en sitio  porcentaje local ganados en general
# 0                                 0.00                                33.33  \
# 1                                60.00                                44.44
# 2                                50.00                                22.22
# 3                                 0.00                                11.11
# 4                                40.00                                25.00
# ..                                 ...                                  ...
# 255                              88.24                                61.76
# 256                              47.06                                38.24
# 257                              47.06                                38.24
# 258                              23.53                                11.76
# 259                              76.47                                64.71
#
#      porcentaje local empatados en sitio
# 0                                  25.00  \
# 1                                  40.00
# 2                                  50.00
# 3                                  40.00
# 4                                  20.00
# ..                                   ...
# 255                                 5.88
# 256                                41.18
# 257                                29.41
# 258                                47.06
# 259                                 5.88
#
#      porcentaje local empatados en general
# 0                                    11.11  \
# 1                                    33.33
# 2                                    44.44
# 3                                    33.33
# 4                                    25.00
# ..                                     ...
# 255                                  11.76
# 256                                  38.24
# 257                                  23.53
# 258                                  41.18
# 259                                  20.59
#
#      porcentaje local perdidos en sitio  porcentaje local perdidos en general
# 0                                 75.00                                 55.56  \
# 1                                  0.00                                 22.22
# 2                                  0.00                                 33.33
# 3                                 60.00                                 55.56
# 4                                 40.00                                 50.00
# ..                                  ...                                   ...
# 255                                5.88                                 26.47
# 256                               11.76                                 23.53
# 257                               23.53                                 38.24
# 258                               29.41                                 47.06
# 259                               17.65                                 14.71
#
#      porcentaje visitante ganados en sitio
# 0                                     0.00  \
# 1                                    20.00
# 2                                    20.00
# 3                                    50.00
# 4                                    80.00
# ..                                     ...
# 255                                  17.65
# 256                                  11.76
# 257                                  23.53
# 258                                  11.76
# 259                                  41.18
#
#      porcentaje visitante ganados en general  ...
# 0                                      11.11  ...  \
# 1                                      11.11  ...
# 2                                      33.33  ...
# 3                                      75.00  ...
# 4                                      88.89  ...
# ..                                       ...  ...
# 255                                    23.53  ...
# 256                                     5.88  ...
# 257                                    20.59  ...
# 258                                    29.41  ...
# 259                                    41.18  ...
#
#      proporcion visitante cambios alineacion centrocampista en sitio
# 0                                                 1.00                \
# 1                                                 1.40
# 2                                                 1.60
# 3                                                 2.25
# 4                                                 1.80
# ..                                                 ...
# 255                                               0.88
# 256                                               1.41
# 257                                               1.12
# 258                                               0.82
# 259                                               1.18
#
#      proporcion visitante cambios alineacion centrocampista en general
# 0                                                 0.89                  \
# 1                                                 1.56
# 2                                                 1.33
# 3                                                 1.88
# 4                                                 2.11
# ..                                                 ...
# 255                                               0.88
# 256                                               1.24
# 257                                               0.97
# 258                                               0.74
# 259                                               1.03
#
#      proporcion local cambios alineacion delantero sitio
# 0                                                 1.75    \
# 1                                                 1.20
# 2                                                 0.75
# 3                                                 1.20
# 4                                                 1.60
# ..                                                 ...
# 255                                               1.41
# 256                                               1.12
# 257                                               0.88
# 258                                               0.94
# 259                                               1.00
#
#      proporcion local cambios alineacion delantero en general
# 0                                                 2.22         \
# 1                                                 1.56
# 2                                                 0.89
# 3                                                 1.11
# 4                                                 1.88
# ..                                                 ...
# 255                                               1.21
# 256                                               1.26
# 257                                               0.91
# 258                                               1.32
# 259                                               1.15
#
#      proporcion visitante cambios alineacion delantero en sitio
# 0                                                 2.00           \
# 1                                                 0.80
# 2                                                 1.80
# 3                                                 1.50
# 4                                                 0.80
# ..                                                 ...
# 255                                               0.88
# 256                                               1.12
# 257                                               1.00
# 258                                               1.00
# 259                                               1.65
#
#      proporcion visitante cambios alineacion delantero en general
# 0                                                 1.56             \
# 1                                                 0.89
# 2                                                 1.56
# 3                                                 1.75
# 4                                                 0.78
# ..                                                 ...
# 255                                               0.91
# 256                                               1.09
# 257                                               1.06
# 258                                               0.85
# 259                                               1.59
#
#      resultado_local  resultado_visitante  resultado_partido  jornada
# 0                  2                    0                  1       10
# 1                  1                    0                  1       10
# 2                  1                    1                  X       10
# 3                  0                    3                  2       10
# 4                  1                    1                  X       10
# ..               ...                  ...                ...      ...
# 255                1                    0                  1       35
# 256                3                    2                  1       35
# 257                0                    0                  X       35
# 258                1                    0                  1       35
# 259                2                    0                  1       35
#
# [260 rows x 174 columns]

# %%
# Eliminar la columna id_partido
df.drop(['id_partido','jornada','id_indicadores_equipo_prepartido'], axis=1, inplace=True)

# %%
df
# Out:
#      porcentaje local ganados en sitio  porcentaje local ganados en general
# 0                                 0.00                                33.33  \
# 1                                60.00                                44.44
# 2                                50.00                                22.22
# 3                                 0.00                                11.11
# 4                                40.00                                25.00
# ..                                 ...                                  ...
# 255                              88.24                                61.76
# 256                              47.06                                38.24
# 257                              47.06                                38.24
# 258                              23.53                                11.76
# 259                              76.47                                64.71
#
#      porcentaje local empatados en sitio
# 0                                  25.00  \
# 1                                  40.00
# 2                                  50.00
# 3                                  40.00
# 4                                  20.00
# ..                                   ...
# 255                                 5.88
# 256                                41.18
# 257                                29.41
# 258                                47.06
# 259                                 5.88
#
#      porcentaje local empatados en general
# 0                                    11.11  \
# 1                                    33.33
# 2                                    44.44
# 3                                    33.33
# 4                                    25.00
# ..                                     ...
# 255                                  11.76
# 256                                  38.24
# 257                                  23.53
# 258                                  41.18
# 259                                  20.59
#
#      porcentaje local perdidos en sitio  porcentaje local perdidos en general
# 0                                 75.00                                 55.56  \
# 1                                  0.00                                 22.22
# 2                                  0.00                                 33.33
# 3                                 60.00                                 55.56
# 4                                 40.00                                 50.00
# ..                                  ...                                   ...
# 255                                5.88                                 26.47
# 256                               11.76                                 23.53
# 257                               23.53                                 38.24
# 258                               29.41                                 47.06
# 259                               17.65                                 14.71
#
#      porcentaje visitante ganados en sitio
# 0                                     0.00  \
# 1                                    20.00
# 2                                    20.00
# 3                                    50.00
# 4                                    80.00
# ..                                     ...
# 255                                  17.65
# 256                                  11.76
# 257                                  23.53
# 258                                  11.76
# 259                                  41.18
#
#      porcentaje visitante ganados en general
# 0                                      11.11  \
# 1                                      11.11
# 2                                      33.33
# 3                                      75.00
# 4                                      88.89
# ..                                       ...
# 255                                    23.53
# 256                                     5.88
# 257                                    20.59
# 258                                    29.41
# 259                                    41.18
#
#      porcentaje visitante empatados en sitio
# 0                                      25.00  \
# 1                                      40.00
# 2                                      40.00
# 3                                      25.00
# 4                                       0.00
# ..                                       ...
# 255                                    29.41
# 256                                    17.65
# 257                                    29.41
# 258                                    47.06
# 259                                    35.29
#
#      porcentaje visitante empatados en general  ...
# 0                                        33.33  ...  \
# 1                                        55.56  ...
# 2                                        44.44  ...
# 3                                        12.50  ...
# 4                                         0.00  ...
# ..                                         ...  ...
# 255                                      29.41  ...
# 256                                      32.35  ...
# 257                                      38.24  ...
# 258                                      38.24  ...
# 259                                      35.29  ...
#
#      proporcion local cambios alineacion centrocampista en general
# 0                                                 1.56              \
# 1                                                 1.67
# 2                                                 0.78
# 3                                                 0.78
# 4                                                 1.25
# ..                                                 ...
# 255                                               1.26
# 256                                               1.29
# 257                                               0.62
# 258                                               0.71
# 259                                               1.15
#
#      proporcion visitante cambios alineacion centrocampista en sitio
# 0                                                 1.00                \
# 1                                                 1.40
# 2                                                 1.60
# 3                                                 2.25
# 4                                                 1.80
# ..                                                 ...
# 255                                               0.88
# 256                                               1.41
# 257                                               1.12
# 258                                               0.82
# 259                                               1.18
#
#      proporcion visitante cambios alineacion centrocampista en general
# 0                                                 0.89                  \
# 1                                                 1.56
# 2                                                 1.33
# 3                                                 1.88
# 4                                                 2.11
# ..                                                 ...
# 255                                               0.88
# 256                                               1.24
# 257                                               0.97
# 258                                               0.74
# 259                                               1.03
#
#      proporcion local cambios alineacion delantero sitio
# 0                                                 1.75    \
# 1                                                 1.20
# 2                                                 0.75
# 3                                                 1.20
# 4                                                 1.60
# ..                                                 ...
# 255                                               1.41
# 256                                               1.12
# 257                                               0.88
# 258                                               0.94
# 259                                               1.00
#
#      proporcion local cambios alineacion delantero en general
# 0                                                 2.22         \
# 1                                                 1.56
# 2                                                 0.89
# 3                                                 1.11
# 4                                                 1.88
# ..                                                 ...
# 255                                               1.21
# 256                                               1.26
# 257                                               0.91
# 258                                               1.32
# 259                                               1.15
#
#      proporcion visitante cambios alineacion delantero en sitio
# 0                                                 2.00           \
# 1                                                 0.80
# 2                                                 1.80
# 3                                                 1.50
# 4                                                 0.80
# ..                                                 ...
# 255                                               0.88
# 256                                               1.12
# 257                                               1.00
# 258                                               1.00
# 259                                               1.65
#
#      proporcion visitante cambios alineacion delantero en general
# 0                                                 1.56             \
# 1                                                 0.89
# 2                                                 1.56
# 3                                                 1.75
# 4                                                 0.78
# ..                                                 ...
# 255                                               0.91
# 256                                               1.09
# 257                                               1.06
# 258                                               0.85
# 259                                               1.59
#
#      resultado_local  resultado_visitante  resultado_partido
# 0                  2                    0                  1
# 1                  1                    0                  1
# 2                  1                    1                  X
# 3                  0                    3                  2
# 4                  1                    1                  X
# ..               ...                  ...                ...
# 255                1                    0                  1
# 256                3                    2                  1
# 257                0                    0                  X
# 258                1                    0                  1
# 259                2                    0                  1
#
# [260 rows x 171 columns]

# %%
# Separar las características (porcentajes) y la clase a predecir (resultado_partido)
X = df.drop(['resultado_partido','resultado_local','resultado_visitante'], axis=1)

# %%
X
# Out:
#      porcentaje local ganados en sitio  porcentaje local ganados en general
# 0                                 0.00                                33.33  \
# 1                                60.00                                44.44
# 2                                50.00                                22.22
# 3                                 0.00                                11.11
# 4                                40.00                                25.00
# ..                                 ...                                  ...
# 255                              88.24                                61.76
# 256                              47.06                                38.24
# 257                              47.06                                38.24
# 258                              23.53                                11.76
# 259                              76.47                                64.71
#
#      porcentaje local empatados en sitio
# 0                                  25.00  \
# 1                                  40.00
# 2                                  50.00
# 3                                  40.00
# 4                                  20.00
# ..                                   ...
# 255                                 5.88
# 256                                41.18
# 257                                29.41
# 258                                47.06
# 259                                 5.88
#
#      porcentaje local empatados en general
# 0                                    11.11  \
# 1                                    33.33
# 2                                    44.44
# 3                                    33.33
# 4                                    25.00
# ..                                     ...
# 255                                  11.76
# 256                                  38.24
# 257                                  23.53
# 258                                  41.18
# 259                                  20.59
#
#      porcentaje local perdidos en sitio  porcentaje local perdidos en general
# 0                                 75.00                                 55.56  \
# 1                                  0.00                                 22.22
# 2                                  0.00                                 33.33
# 3                                 60.00                                 55.56
# 4                                 40.00                                 50.00
# ..                                  ...                                   ...
# 255                                5.88                                 26.47
# 256                               11.76                                 23.53
# 257                               23.53                                 38.24
# 258                               29.41                                 47.06
# 259                               17.65                                 14.71
#
#      porcentaje visitante ganados en sitio
# 0                                     0.00  \
# 1                                    20.00
# 2                                    20.00
# 3                                    50.00
# 4                                    80.00
# ..                                     ...
# 255                                  17.65
# 256                                  11.76
# 257                                  23.53
# 258                                  11.76
# 259                                  41.18
#
#      porcentaje visitante ganados en general
# 0                                      11.11  \
# 1                                      11.11
# 2                                      33.33
# 3                                      75.00
# 4                                      88.89
# ..                                       ...
# 255                                    23.53
# 256                                     5.88
# 257                                    20.59
# 258                                    29.41
# 259                                    41.18
#
#      porcentaje visitante empatados en sitio
# 0                                      25.00  \
# 1                                      40.00
# 2                                      40.00
# 3                                      25.00
# 4                                       0.00
# ..                                       ...
# 255                                    29.41
# 256                                    17.65
# 257                                    29.41
# 258                                    47.06
# 259                                    35.29
#
#      porcentaje visitante empatados en general  ...
# 0                                        33.33  ...  \
# 1                                        55.56  ...
# 2                                        44.44  ...
# 3                                        12.50  ...
# 4                                         0.00  ...
# ..                                         ...  ...
# 255                                      29.41  ...
# 256                                      32.35  ...
# 257                                      38.24  ...
# 258                                      38.24  ...
# 259                                      35.29  ...
#
#      proporcion visitante cambios alineacion defensa en sitio
# 0                                                 1.75         \
# 1                                                 2.00
# 2                                                 2.20
# 3                                                 2.00
# 4                                                 1.60
# ..                                                 ...
# 255                                               1.29
# 256                                               2.00
# 257                                               1.12
# 258                                               1.76
# 259                                               1.94
#
#      proporcion visitante cambios alineacion defensa en general
# 0                                                 1.67           \
# 1                                                 2.33
# 2                                                 2.00
# 3                                                 1.88
# 4                                                 1.67
# ..                                                 ...
# 255                                               1.29
# 256                                               1.79
# 257                                               1.00
# 258                                               1.85
# 259                                               1.59
#
#      proporcion local cambios alineacion centrocampista sitio
# 0                                                 1.75         \
# 1                                                 1.60
# 2                                                 1.00
# 3                                                 0.60
# 4                                                 1.20
# ..                                                 ...
# 255                                               1.12
# 256                                               1.24
# 257                                               0.65
# 258                                               0.59
# 259                                               1.06
#
#      proporcion local cambios alineacion centrocampista en general
# 0                                                 1.56              \
# 1                                                 1.67
# 2                                                 0.78
# 3                                                 0.78
# 4                                                 1.25
# ..                                                 ...
# 255                                               1.26
# 256                                               1.29
# 257                                               0.62
# 258                                               0.71
# 259                                               1.15
#
#      proporcion visitante cambios alineacion centrocampista en sitio
# 0                                                 1.00                \
# 1                                                 1.40
# 2                                                 1.60
# 3                                                 2.25
# 4                                                 1.80
# ..                                                 ...
# 255                                               0.88
# 256                                               1.41
# 257                                               1.12
# 258                                               0.82
# 259                                               1.18
#
#      proporcion visitante cambios alineacion centrocampista en general
# 0                                                 0.89                  \
# 1                                                 1.56
# 2                                                 1.33
# 3                                                 1.88
# 4                                                 2.11
# ..                                                 ...
# 255                                               0.88
# 256                                               1.24
# 257                                               0.97
# 258                                               0.74
# 259                                               1.03
#
#      proporcion local cambios alineacion delantero sitio
# 0                                                 1.75    \
# 1                                                 1.20
# 2                                                 0.75
# 3                                                 1.20
# 4                                                 1.60
# ..                                                 ...
# 255                                               1.41
# 256                                               1.12
# 257                                               0.88
# 258                                               0.94
# 259                                               1.00
#
#      proporcion local cambios alineacion delantero en general
# 0                                                 2.22         \
# 1                                                 1.56
# 2                                                 0.89
# 3                                                 1.11
# 4                                                 1.88
# ..                                                 ...
# 255                                               1.21
# 256                                               1.26
# 257                                               0.91
# 258                                               1.32
# 259                                               1.15
#
#      proporcion visitante cambios alineacion delantero en sitio
# 0                                                 2.00           \
# 1                                                 0.80
# 2                                                 1.80
# 3                                                 1.50
# 4                                                 0.80
# ..                                                 ...
# 255                                               0.88
# 256                                               1.12
# 257                                               1.00
# 258                                               1.00
# 259                                               1.65
#
#      proporcion visitante cambios alineacion delantero en general
# 0                                                 1.56
# 1                                                 0.89
# 2                                                 1.56
# 3                                                 1.75
# 4                                                 0.78
# ..                                                 ...
# 255                                               0.91
# 256                                               1.09
# 257                                               1.06
# 258                                               0.85
# 259                                               1.59
#
# [260 rows x 168 columns]

# %%
y_resultado=df['resultado_partido']
y_resultado_local=df['resultado_local']
y_resultado_visitante=df['resultado_visitante']

# %%
y_resultado
# Out:
# 0      1
# 1      1
# 2      X
# 3      2
# 4      X
#       ..
# 255    1
# 256    1
# 257    X
# 258    1
# 259    1
# Name: resultado_partido, Length: 260, dtype: object

# %%
y_resultado_local
# Out:
# 0      2
# 1      1
# 2      1
# 3      0
# 4      1
#       ..
# 255    1
# 256    3
# 257    0
# 258    1
# 259    2
# Name: resultado_local, Length: 260, dtype: int64

# %%
y_resultado_visitante
# Out:
# 0      0
# 1      0
# 2      1
# 3      3
# 4      1
#       ..
# 255    0
# 256    2
# 257    0
# 258    0
# 259    0
# Name: resultado_visitante, Length: 260, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_resultado, test_size=0.2, random_state=42)

# %%
model = LogisticRegression(multi_class='multinomial', solver='lbfgs', max_iter=1000)
model.fit(X_train, y_train)
# Out:
# c:\Users\jmlozanoo\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(max_iter=1000, multi_class='multinomial')

# %%
accuracy = model.score(X_test, y_test)

# Imprimir la precisión del modelo sobre el conjunto de prueba
print(f"\nPrecisión del modelo sobre el conjunto de prueba: {accuracy:.2f}")
# Out:
# Precisión del modelo sobre el conjunto de prueba: 0.42

# %%
#para predecir
new_data = [[14.29,28.57,28.57,14.29,57.14,57.14,33.33,50.0,33.33,28.57,33.33,21.43,0.71,1.0,1.33,1.79,85.71,92.86,66.67,71.43,28.57,50.0,66.67,57.14,14.29,28.57,33.33,28.57,14.29,14.29,0.0,14.29,2.43,2.86,0.86,1.14,1.57,1.71,2.5,3.0,1.33,1.79,1.17,1.21,57.14,71.43,28.57,42.86,0.0,0.0,71.43,71.43,57.14,57.14,14.29,28.57,83.33,85.71,33.33,42.86,16.67,28.57,66.67,71.43,50.0,35.71,0.0,14.29,2.29,2.29,3.5,2.86,0.43,0.21,0.0,0.0,4.86,4.93,4.5,4.64,48.43,47.57,53.0,53.21,13.71,11.5,11.83,12.0,5.43,4.21,4.33,4.43,4.43,4.79,3.17,3.71,0.0,0.21,0.33,0.5,1.0,0.79,1.17,0.86,0.14,0.36,0.67,0.71,0.14,0.14,0.33,0.43,75.91,74.14,67.89,69.06,0.43,0.5,0.17,0.14,0.0,0.21,0.17,0.14,0.71,0.79,0.5,0.29,0.14,0.29,0.17,0.14,0.71,0.64,0.17,0.29,0.0,0.0,0.17,0.07,0.0,0.0,0.0,0.07,0.14,0.29,1.33,1.07,2.14,2.07,1.67,1.79,2.57,2.57,1.5,1.71,1.86,1.71,2.17,1.79,1.14,1.07,1.33,1.14,1.14,1.64,1.67,1.57]]

# %%
predicted_probabilities = model.predict_proba(new_data)
# Out:
# c:\Users\jmlozanoo\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
predicted_probabilities = model.predict_proba(X_test)

# %%
class_names = model.classes_
for i, (probs, true_class) in enumerate(zip(predicted_probabilities, y_test)):
    print(f"Partido {i+1}:")
    print(f"  Clase real: {true_class}")
    for class_name, prob in zip(class_names, probs):
        print(f"  Probabilidad de {class_name}: {prob:.4f}")
# Out:
# Partido 1:
#   Clase real: 1
#   Probabilidad de 1: 0.2115
#   Probabilidad de 2: 0.0000
#   Probabilidad de X: 0.7885
# Partido 2:
#   Clase real: 1
#   Probabilidad de 1: 0.9997
#   Probabilidad de 2: 0.0000
#   Probabilidad de X: 0.0003
# Partido 3:
#   Clase real: 1
#   Probabilidad de 1: 0.9942
#   Probabilidad de 2: 0.0000
#   Probabilidad de X: 0.0058
# Partido 4:
#   Clase real: 2
#   Probabilidad de 1: 0.9905
#   Probabilidad de 2: 0.0001
#   Probabilidad de X: 0.0094
# Partido 5:
#   Clase real: 1
#   Probabilidad de 1: 0.4864
#   Probabilidad de 2: 0.0000
#   Probabilidad de X: 0.5136
# Partido 6:
#   Clase real: 1
#   Probabilidad de 1: 0.2576
#   Probabilidad de 2: 0.0285
#   Probabilidad de X: 0.7139
# Partido 7:
#   Clase real: 1
#   Probabilidad de 1: 0.0197
#   Probabilidad de 2: 0.9482
#   Probabilidad de X: 0.0321
# Partido 8:
#   Clase real: 1
#   Probabilidad de 1: 0.4515
#   Probabilidad de 2: 0.5477
#   Probabilidad de X: 0.0008
# Partido 9:
#   Clase real: 1
#   Probabilidad de 1: 0.9998
#   Probabilidad de 2: 0.0000
#   Probabilidad de X: 0.0002
# Partido 10:
#   Clase real: 1
#   Probabilidad de 1: 0.9926
#   Probabilidad de 2: 0.0001
#   Probabilidad de X: 0.0074
# Partido 11:
#   Clase real: 2
#   Probabilidad de 1: 0.8013
#   Probabilidad de 2: 0.1737
#   Probabilidad de X: 0.0251
# Partido 12:
#   Clase real: X
#   Probabilidad de 1: 0.7234
#   Probabilidad de 2: 0.1868
#   Probabilidad de X: 0.0899
# Partido 13:
#   Clase real: X
#   Probabilidad de 1: 0.0000
#   Probabilidad de 2: 0.0000
#   Probabilidad de X: 0.9999
# Partido 14:
#   Clase real: 1
#   Probabilidad de 1: 0.9786
#   Probabilidad de 2: 0.0000
#   Probabilidad de X: 0.0214
# Partido 15:
#   Clase real: 1
#   Probabilidad de 1: 0.9989
#   Probabilidad de 2: 0.0000
#   Probabilidad de X: 0.0011
# Partido 16:
#   Clase real: 1
#   Probabilidad de 1: 0.9991
#   Probabilidad de 2: 0.0000
#   Probabilidad de X: 0.0009
# Partido 17:
#   Clase real: 2
#   Probabilidad de 1: 0.0518
#   Probabilidad de 2: 0.9301
#   Probabilidad de X: 0.0182
# Partido 18:
#   Clase real: 2
#   Probabilidad de 1: 0.9947
#   Probabilidad de 2: 0.0000
#   Probabilidad de X: 0.0053
# Partido 19:
#   Clase real: X
#   Probabilidad de 1: 0.9458
#   Probabilidad de 2: 0.0000
#   Probabilidad de X: 0.0542
# Partido 20:
#   Clase real: 1
#   Probabilidad de 1: 0.9279
#   Probabilidad de 2: 0.0000
#   Probabilidad de X: 0.0721
# Partido 21:
#   Clase real: 1
#   Probabilidad de 1: 0.3760
#   Probabilidad de 2: 0.0000
#   Probabilidad de X: 0.6240
# Partido 22:
#   Clase real: 2
#   Probabilidad de 1: 0.8118
#   Probabilidad de 2: 0.0002
#   Probabilidad de X: 0.1881
# Partido 23:
#   Clase real: 2
#   Probabilidad de 1: 0.0000
#   Probabilidad de 2: 1.0000
#   Probabilidad de X: 0.0000
# Partido 24:
#   Clase real: X
#   Probabilidad de 1: 0.0875
#   Probabilidad de 2: 0.1169
#   Probabilidad de X: 0.7956
# Partido 25:
#   Clase real: 1
#   Probabilidad de 1: 0.8920
#   Probabilidad de 2: 0.0000
#   Probabilidad de X: 0.1080
# Partido 26:
#   Clase real: 1
#   Probabilidad de 1: 0.0089
#   Probabilidad de 2: 0.8447
#   Probabilidad de X: 0.1463
# Partido 27:
#   Clase real: 1
#   Probabilidad de 1: 0.1183
#   Probabilidad de 2: 0.0000
#   Probabilidad de X: 0.8817
# Partido 28:
#   Clase real: 1
#   Probabilidad de 1: 0.0000
#   Probabilidad de 2: 0.0000
#   Probabilidad de X: 1.0000
# Partido 29:
#   Clase real: 2
#   Probabilidad de 1: 0.0000
#   Probabilidad de 2: 0.9999
#   Probabilidad de X: 0.0001
# Partido 30:
#   Clase real: 1
#   Probabilidad de 1: 0.9865
#   Probabilidad de 2: 0.0135
#   Probabilidad de X: 0.0000
# Partido 31:
#   Clase real: X
#   Probabilidad de 1: 0.0670
#   Probabilidad de 2: 0.3033
#   Probabilidad de X: 0.6297
# Partido 32:
#   Clase real: X
#   Probabilidad de 1: 0.0064
#   Probabilidad de 2: 0.9732
#   Probabilidad de X: 0.0204
# Partido 33:
#   Clase real: X
#   Probabilidad de 1: 0.8346
#   Probabilidad de 2: 0.0339
#   Probabilidad de X: 0.1315
# Partido 34:
#   Clase real: X
#   Probabilidad de 1: 0.0002
#   Probabilidad de 2: 0.0515
#   Probabilidad de X: 0.9483
# Partido 35:
#   Clase real: 2
#   Probabilidad de 1: 0.9539
#   Probabilidad de 2: 0.0065
#   Probabilidad de X: 0.0396
# Partido 36:
#   Clase real: 1
#   Probabilidad de 1: 0.3030
#   Probabilidad de 2: 0.0000
#   Probabilidad de X: 0.6970
# Partido 37:
#   Clase real: 2
#   Probabilidad de 1: 0.0008
#   Probabilidad de 2: 0.9458
#   Probabilidad de X: 0.0534
# Partido 38:
#   Clase real: 1
#   Probabilidad de 1: 0.8641
#   Probabilidad de 2: 0.0000
#   Probabilidad de X: 0.1359
# Partido 39:
#   Clase real: 1
#   Probabilidad de 1: 0.2451
#   Probabilidad de 2: 0.0000
#   Probabilidad de X: 0.7549
# Partido 40:
#   Clase real: 1
#   Probabilidad de 1: 0.0110
#   Probabilidad de 2: 0.0000
#   Probabilidad de X: 0.9890
# Partido 41:
#   Clase real: 2
#   Probabilidad de 1: 0.6745
#   Probabilidad de 2: 0.0014
#   Probabilidad de X: 0.3242
# Partido 42:
#   Clase real: X
#   Probabilidad de 1: 0.9446
#   Probabilidad de 2: 0.0487
#   Probabilidad de X: 0.0068
# Partido 43:
#   Clase real: 1
#   Probabilidad de 1: 0.9613
#   Probabilidad de 2: 0.0000
#   Probabilidad de X: 0.0387
# Partido 44:
#   Clase real: X
#   Probabilidad de 1: 0.9985
#   Probabilidad de 2: 0.0005
#   Probabilidad de X: 0.0009
# Partido 45:
#   Clase real: X
#   Probabilidad de 1: 1.0000
#   Probabilidad de 2: 0.0000
#   Probabilidad de X: 0.0000
# Partido 46:
#   Clase real: 1
#   Probabilidad de 1: 0.4735
#   Probabilidad de 2: 0.0338
#   Probabilidad de X: 0.4927
# Partido 47:
#   Clase real: 2
#   Probabilidad de 1: 0.0512
#   Probabilidad de 2: 0.0110
#   Probabilidad de X: 0.9379
# Partido 48:
#   Clase real: X
#   Probabilidad de 1: 0.2025
#   Probabilidad de 2: 0.0539
#   Probabilidad de X: 0.7437
# Partido 49:
#   Clase real: 1
#   Probabilidad de 1: 0.9849
#   Probabilidad de 2: 0.0144
#   Probabilidad de X: 0.0007
# Partido 50:
#   Clase real: X
#   Probabilidad de 1: 0.5598
#   Probabilidad de 2: 0.2842
#   Probabilidad de X: 0.1560
# Partido 51:
#   Clase real: X
#   Probabilidad de 1: 0.0000
#   Probabilidad de 2: 1.0000
#   Probabilidad de X: 0.0000
# Partido 52:
#   Clase real: 2
#   Probabilidad de 1: 0.0783
#   Probabilidad de 2: 0.4122
#   Probabilidad de X: 0.5095
