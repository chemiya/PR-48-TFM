# %%
import numpy as np
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
import tensorflow as tf
import pandas as pd
from sklearn.preprocessing import OneHotEncoder
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv('indicadoresEquipoHistoricoModelo.csv',sep=",")
df
# Out:
#      id_indicadores_equipo_prepartido  id_partido
# 0                                89.0        98.0  \
# 1                                90.0        96.0
# 2                                91.0        94.0
# 3                                92.0        93.0
# 4                                93.0        97.0
# ..                                ...         ...
# 255                             345.0       341.0
# 256                             346.0       346.0
# 257                             347.0       348.0
# 258                             348.0       342.0
# 259                             349.0       344.0
#
#      porcentaje local ganados en sitio  porcentaje local ganados en general
# 0                                 0.00                                33.33  \
# 1                                60.00                                44.44
# 2                                50.00                                22.22
# 3                                 0.00                                11.11
# 4                                40.00                                25.00
# ..                                 ...                                  ...
# 255                              88.24                                61.76
# 256                              47.06                                38.24
# 257                              47.06                                38.24
# 258                              23.53                                11.76
# 259                              76.47                                64.71
#
#      porcentaje local empatados en sitio
# 0                                  25.00  \
# 1                                  40.00
# 2                                  50.00
# 3                                  40.00
# 4                                  20.00
# ..                                   ...
# 255                                 5.88
# 256                                41.18
# 257                                29.41
# 258                                47.06
# 259                                 5.88
#
#      porcentaje local empatados en general
# 0                                    11.11  \
# 1                                    33.33
# 2                                    44.44
# 3                                    33.33
# 4                                    25.00
# ..                                     ...
# 255                                  11.76
# 256                                  38.24
# 257                                  23.53
# 258                                  41.18
# 259                                  20.59
#
#      porcentaje local perdidos en sitio  porcentaje local perdidos en general
# 0                                 75.00                                 55.56  \
# 1                                  0.00                                 22.22
# 2                                  0.00                                 33.33
# 3                                 60.00                                 55.56
# 4                                 40.00                                 50.00
# ..                                  ...                                   ...
# 255                                5.88                                 26.47
# 256                               11.76                                 23.53
# 257                               23.53                                 38.24
# 258                               29.41                                 47.06
# 259                               17.65                                 14.71
#
#      porcentaje visitante ganados en sitio
# 0                                     0.00  \
# 1                                    20.00
# 2                                    20.00
# 3                                    50.00
# 4                                    80.00
# ..                                     ...
# 255                                  17.65
# 256                                  11.76
# 257                                  23.53
# 258                                  11.76
# 259                                  41.18
#
#      porcentaje visitante ganados en general  ...
# 0                                      11.11  ...  \
# 1                                      11.11  ...
# 2                                      33.33  ...
# 3                                      75.00  ...
# 4                                      88.89  ...
# ..                                       ...  ...
# 255                                    23.53  ...
# 256                                     5.88  ...
# 257                                    20.59  ...
# 258                                    29.41  ...
# 259                                    41.18  ...
#
#      proporcion visitante cambios alineacion centrocampista en sitio
# 0                                                 1.00                \
# 1                                                 1.40
# 2                                                 1.60
# 3                                                 2.25
# 4                                                 1.80
# ..                                                 ...
# 255                                               0.88
# 256                                               1.41
# 257                                               1.12
# 258                                               0.82
# 259                                               1.18
#
#      proporcion visitante cambios alineacion centrocampista en general
# 0                                                 0.89                  \
# 1                                                 1.56
# 2                                                 1.33
# 3                                                 1.88
# 4                                                 2.11
# ..                                                 ...
# 255                                               0.88
# 256                                               1.24
# 257                                               0.97
# 258                                               0.74
# 259                                               1.03
#
#      proporcion local cambios alineacion delantero sitio
# 0                                                 1.75    \
# 1                                                 1.20
# 2                                                 0.75
# 3                                                 1.20
# 4                                                 1.60
# ..                                                 ...
# 255                                               1.41
# 256                                               1.12
# 257                                               0.88
# 258                                               0.94
# 259                                               1.00
#
#      proporcion local cambios alineacion delantero en general
# 0                                                 2.22         \
# 1                                                 1.56
# 2                                                 0.89
# 3                                                 1.11
# 4                                                 1.88
# ..                                                 ...
# 255                                               1.21
# 256                                               1.26
# 257                                               0.91
# 258                                               1.32
# 259                                               1.15
#
#      proporcion visitante cambios alineacion delantero en sitio
# 0                                                 2.00           \
# 1                                                 0.80
# 2                                                 1.80
# 3                                                 1.50
# 4                                                 0.80
# ..                                                 ...
# 255                                               0.88
# 256                                               1.12
# 257                                               1.00
# 258                                               1.00
# 259                                               1.65
#
#      proporcion visitante cambios alineacion delantero en general
# 0                                                 1.56             \
# 1                                                 0.89
# 2                                                 1.56
# 3                                                 1.75
# 4                                                 0.78
# ..                                                 ...
# 255                                               0.91
# 256                                               1.09
# 257                                               1.06
# 258                                               0.85
# 259                                               1.59
#
#      resultado_local  resultado_visitante  resultado_partido  jornada
# 0                  2                    0                  1       10
# 1                  1                    0                  1       10
# 2                  1                    1                  X       10
# 3                  0                    3                  2       10
# 4                  1                    1                  X       10
# ..               ...                  ...                ...      ...
# 255                1                    0                  1       35
# 256                3                    2                  1       35
# 257                0                    0                  X       35
# 258                1                    0                  1       35
# 259                2                    0                  1       35
#
# [260 rows x 174 columns]

# %%
# Eliminar la columna id_partido
df.drop(['id_partido','jornada','id_indicadores_equipo_prepartido'], axis=1, inplace=True)

# %%
# Separar las características (porcentajes) y la clase a predecir (resultado_partido)
X = df.drop(['resultado_partido','resultado_local','resultado_visitante'], axis=1)

# %%
y_resultado=df['resultado_partido']
y_resultado_local=df['resultado_local']
y_resultado_visitante=df['resultado_visitante']

# %%
# Codificar las etiquetas (resultado_partido)
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y_resultado)

# Convertir las etiquetas a one-hot encoding
y_categorical = to_categorical(y_encoded)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_categorical, test_size=0.2, random_state=42)

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(3, activation='softmax')  # Capa de salida con 3 neuronas para las 3 clases
])

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(X_train, y_train, epochs=50, batch_size=16, validation_split=0.1)
# Out:
# Epoch 1/50
# 12/12 [==============================] - 1s 17ms/step - loss: 7.2772 - accuracy: 0.4332 - val_loss: 9.8383 - val_accuracy: 0.2381
# Epoch 2/50
# 12/12 [==============================] - 0s 4ms/step - loss: 7.2326 - accuracy: 0.3797 - val_loss: 2.8354 - val_accuracy: 0.5714
# Epoch 3/50
# 12/12 [==============================] - 0s 4ms/step - loss: 3.5539 - accuracy: 0.4225 - val_loss: 2.8990 - val_accuracy: 0.6667
# Epoch 4/50
# 12/12 [==============================] - 0s 4ms/step - loss: 3.1055 - accuracy: 0.4706 - val_loss: 2.2685 - val_accuracy: 0.5714
# Epoch 5/50
# 12/12 [==============================] - 0s 5ms/step - loss: 2.6439 - accuracy: 0.4759 - val_loss: 2.7568 - val_accuracy: 0.1905
# Epoch 6/50
# 12/12 [==============================] - 0s 3ms/step - loss: 2.8911 - accuracy: 0.4973 - val_loss: 1.8511 - val_accuracy: 0.4762
# Epoch 7/50
# 12/12 [==============================] - 0s 4ms/step - loss: 1.6901 - accuracy: 0.5401 - val_loss: 1.8211 - val_accuracy: 0.4762
# Epoch 8/50
# 12/12 [==============================] - 0s 4ms/step - loss: 1.3233 - accuracy: 0.5401 - val_loss: 1.9799 - val_accuracy: 0.4762
# Epoch 9/50
# 12/12 [==============================] - 0s 4ms/step - loss: 1.2660 - accuracy: 0.5508 - val_loss: 2.3866 - val_accuracy: 0.3333
# Epoch 10/50
# 12/12 [==============================] - 0s 3ms/step - loss: 1.4281 - accuracy: 0.5882 - val_loss: 2.0857 - val_accuracy: 0.4286
# Epoch 11/50
# 12/12 [==============================] - 0s 3ms/step - loss: 1.2801 - accuracy: 0.5508 - val_loss: 1.9143 - val_accuracy: 0.4762
# Epoch 12/50
# 12/12 [==============================] - 0s 3ms/step - loss: 0.9590 - accuracy: 0.6096 - val_loss: 1.9157 - val_accuracy: 0.3333
# Epoch 13/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.9742 - accuracy: 0.6203 - val_loss: 1.9642 - val_accuracy: 0.4286
# Epoch 14/50
# 12/12 [==============================] - 0s 3ms/step - loss: 1.0240 - accuracy: 0.6150 - val_loss: 1.9038 - val_accuracy: 0.6190
# Epoch 15/50
# 12/12 [==============================] - 0s 3ms/step - loss: 1.0000 - accuracy: 0.6043 - val_loss: 2.5981 - val_accuracy: 0.4762
# Epoch 16/50
# 12/12 [==============================] - 0s 3ms/step - loss: 1.3833 - accuracy: 0.5936 - val_loss: 3.3752 - val_accuracy: 0.3333
# Epoch 17/50
# 12/12 [==============================] - 0s 3ms/step - loss: 1.1861 - accuracy: 0.5668 - val_loss: 2.6165 - val_accuracy: 0.4762
# Epoch 18/50
# 12/12 [==============================] - 0s 4ms/step - loss: 1.1153 - accuracy: 0.6203 - val_loss: 2.5043 - val_accuracy: 0.2381
# Epoch 19/50
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0360 - accuracy: 0.6364 - val_loss: 1.7115 - val_accuracy: 0.4286
# Epoch 20/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.7386 - accuracy: 0.6952 - val_loss: 1.9234 - val_accuracy: 0.4286
# Epoch 21/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.8525 - accuracy: 0.6898 - val_loss: 2.5803 - val_accuracy: 0.1429
# Epoch 22/50
# 12/12 [==============================] - 0s 3ms/step - loss: 0.9867 - accuracy: 0.6471 - val_loss: 2.2766 - val_accuracy: 0.5238
# Epoch 23/50
# 12/12 [==============================] - 0s 3ms/step - loss: 1.0926 - accuracy: 0.6257 - val_loss: 2.3076 - val_accuracy: 0.3333
# Epoch 24/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.8421 - accuracy: 0.6578 - val_loss: 2.1432 - val_accuracy: 0.3333
# Epoch 25/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.8554 - accuracy: 0.6738 - val_loss: 2.1076 - val_accuracy: 0.3810
# Epoch 26/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6704 - accuracy: 0.7273 - val_loss: 2.7239 - val_accuracy: 0.3333
# Epoch 27/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.9454 - accuracy: 0.6096 - val_loss: 2.4409 - val_accuracy: 0.5238
# Epoch 28/50
# 12/12 [==============================] - 0s 4ms/step - loss: 1.1427 - accuracy: 0.6096 - val_loss: 1.9814 - val_accuracy: 0.2857
# Epoch 29/50
# 12/12 [==============================] - 0s 3ms/step - loss: 1.2147 - accuracy: 0.5936 - val_loss: 2.2357 - val_accuracy: 0.4286
# Epoch 30/50
# 12/12 [==============================] - 0s 4ms/step - loss: 1.2296 - accuracy: 0.5936 - val_loss: 1.5504 - val_accuracy: 0.4286
# Epoch 31/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.9575 - accuracy: 0.6471 - val_loss: 2.0960 - val_accuracy: 0.4286
# Epoch 32/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.7240 - accuracy: 0.6845 - val_loss: 1.9212 - val_accuracy: 0.3333
# Epoch 33/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.5477 - accuracy: 0.7861 - val_loss: 1.9593 - val_accuracy: 0.3333
# Epoch 34/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.5544 - accuracy: 0.7166 - val_loss: 1.8409 - val_accuracy: 0.4286
# Epoch 35/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4644 - accuracy: 0.8075 - val_loss: 1.7072 - val_accuracy: 0.4286
# Epoch 36/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.4625 - accuracy: 0.7807 - val_loss: 1.9070 - val_accuracy: 0.3333
# Epoch 37/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4237 - accuracy: 0.8342 - val_loss: 1.6107 - val_accuracy: 0.4762
# Epoch 38/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.4189 - accuracy: 0.8663 - val_loss: 2.0095 - val_accuracy: 0.3333
# Epoch 39/50
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4351 - accuracy: 0.7968 - val_loss: 1.9178 - val_accuracy: 0.4286
# Epoch 40/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4727 - accuracy: 0.8075 - val_loss: 1.8410 - val_accuracy: 0.3810
# Epoch 41/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4077 - accuracy: 0.8342 - val_loss: 1.9071 - val_accuracy: 0.5238
# Epoch 42/50
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5000 - accuracy: 0.7861 - val_loss: 1.9805 - val_accuracy: 0.4286
# Epoch 43/50
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5406 - accuracy: 0.7701 - val_loss: 1.7747 - val_accuracy: 0.5714
# Epoch 44/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.5932 - accuracy: 0.7487 - val_loss: 1.7888 - val_accuracy: 0.4286
# Epoch 45/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.7159 - accuracy: 0.6898 - val_loss: 2.5017 - val_accuracy: 0.2381
# Epoch 46/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6278 - accuracy: 0.7326 - val_loss: 1.9963 - val_accuracy: 0.3810
# Epoch 47/50
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5345 - accuracy: 0.7487 - val_loss: 1.7082 - val_accuracy: 0.4762
# Epoch 48/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6048 - accuracy: 0.7487 - val_loss: 2.0105 - val_accuracy: 0.3810
# Epoch 49/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4500 - accuracy: 0.8021 - val_loss: 1.7152 - val_accuracy: 0.4762
# Epoch 50/50
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3751 - accuracy: 0.8449 - val_loss: 1.7203 - val_accuracy: 0.3810

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Pérdida en el conjunto de prueba: {loss:.4f}")
print(f"Precisión en el conjunto de prueba: {accuracy:.4f}")
# Out:
# 2/2 [==============================] - 0s 23ms/step - loss: 1.5405 - accuracy: 0.5192
# Pérdida en el conjunto de prueba: 1.5405
# Precisión en el conjunto de prueba: 0.5192

# %%
# Predecir las probabilidades de las clases en el conjunto de prueba
y_pred_proba = model.predict(X_test)

# Decodificar las etiquetas predichas y reales
y_test_decoded = label_encoder.inverse_transform(np.argmax(y_test, axis=1))
y_pred_decoded = label_encoder.inverse_transform(np.argmax(y_pred_proba, axis=1))

# Mostrar las probabilidades para cada clase junto con la clase real
for i, (probs, true_class, pred_class) in enumerate(zip(y_pred_proba, y_test_decoded, y_pred_decoded)):
    print(f"Partido {i+1}:")
    print(f"  Clase real: {true_class}")
    print(f"  Clase predicha: {pred_class}")
    for class_name, prob in zip(label_encoder.classes_, probs):
        print(f"  Probabilidad de {class_name}: {prob:.4f}")
# Out:
# 2/2 [==============================] - 0s 6ms/step
# Partido 1:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.7251
#   Probabilidad de 2: 0.0180
#   Probabilidad de X: 0.2569
# Partido 2:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.8887
#   Probabilidad de 2: 0.0005
#   Probabilidad de X: 0.1108
# Partido 3:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.9999
#   Probabilidad de 2: 0.0000
#   Probabilidad de X: 0.0001
# Partido 4:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.5772
#   Probabilidad de 2: 0.4109
#   Probabilidad de X: 0.0118
# Partido 5:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.6427
#   Probabilidad de 2: 0.0731
#   Probabilidad de X: 0.2842
# Partido 6:
#   Clase real: 1
#   Clase predicha: X
#   Probabilidad de 1: 0.0728
#   Probabilidad de 2: 0.0081
#   Probabilidad de X: 0.9191
# Partido 7:
#   Clase real: 1
#   Clase predicha: 2
#   Probabilidad de 1: 0.0448
#   Probabilidad de 2: 0.9218
#   Probabilidad de X: 0.0334
# Partido 8:
#   Clase real: 1
#   Clase predicha: 2
#   Probabilidad de 1: 0.1647
#   Probabilidad de 2: 0.8205
#   Probabilidad de X: 0.0148
# Partido 9:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.9792
#   Probabilidad de 2: 0.0002
#   Probabilidad de X: 0.0206
# Partido 10:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.7710
#   Probabilidad de 2: 0.0079
#   Probabilidad de X: 0.2210
# Partido 11:
#   Clase real: 2
#   Clase predicha: X
#   Probabilidad de 1: 0.0142
#   Probabilidad de 2: 0.0455
#   Probabilidad de X: 0.9403
# Partido 12:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.5887
#   Probabilidad de 2: 0.1639
#   Probabilidad de X: 0.2474
# Partido 13:
#   Clase real: X
#   Clase predicha: 2
#   Probabilidad de 1: 0.0044
#   Probabilidad de 2: 0.5607
#   Probabilidad de X: 0.4348
# Partido 14:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.8251
#   Probabilidad de 2: 0.0003
#   Probabilidad de X: 0.1746
# Partido 15:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.9807
#   Probabilidad de 2: 0.0007
#   Probabilidad de X: 0.0186
# Partido 16:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.9725
#   Probabilidad de 2: 0.0008
#   Probabilidad de X: 0.0267
# Partido 17:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.8880
#   Probabilidad de 2: 0.0264
#   Probabilidad de X: 0.0856
# Partido 18:
#   Clase real: 2
#   Clase predicha: 2
#   Probabilidad de 1: 0.0360
#   Probabilidad de 2: 0.9401
#   Probabilidad de X: 0.0239
# Partido 19:
#   Clase real: X
#   Clase predicha: X
#   Probabilidad de 1: 0.2313
#   Probabilidad de 2: 0.0000
#   Probabilidad de X: 0.7687
# Partido 20:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.9962
#   Probabilidad de 2: 0.0001
#   Probabilidad de X: 0.0038
# Partido 21:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.7536
#   Probabilidad de 2: 0.0001
#   Probabilidad de X: 0.2463
# Partido 22:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.7871
#   Probabilidad de 2: 0.0018
#   Probabilidad de X: 0.2112
# Partido 23:
#   Clase real: 2
#   Clase predicha: 2
#   Probabilidad de 1: 0.2163
#   Probabilidad de 2: 0.7360
#   Probabilidad de X: 0.0477
# Partido 24:
#   Clase real: X
#   Clase predicha: X
#   Probabilidad de 1: 0.2504
#   Probabilidad de 2: 0.1037
#   Probabilidad de X: 0.6459
# Partido 25:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.9964
#   Probabilidad de 2: 0.0000
#   Probabilidad de X: 0.0036
# Partido 26:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.8956
#   Probabilidad de 2: 0.0654
#   Probabilidad de X: 0.0390
# Partido 27:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.5382
#   Probabilidad de 2: 0.0006
#   Probabilidad de X: 0.4612
# Partido 28:
#   Clase real: 1
#   Clase predicha: X
#   Probabilidad de 1: 0.0021
#   Probabilidad de 2: 0.0560
#   Probabilidad de X: 0.9419
# Partido 29:
#   Clase real: 2
#   Clase predicha: 2
#   Probabilidad de 1: 0.0008
#   Probabilidad de 2: 0.9954
#   Probabilidad de X: 0.0038
# Partido 30:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 1.0000
#   Probabilidad de 2: 0.0000
#   Probabilidad de X: 0.0000
# Partido 31:
#   Clase real: X
#   Clase predicha: X
#   Probabilidad de 1: 0.0682
#   Probabilidad de 2: 0.0257
#   Probabilidad de X: 0.9061
# Partido 32:
#   Clase real: X
#   Clase predicha: 2
#   Probabilidad de 1: 0.1013
#   Probabilidad de 2: 0.8573
#   Probabilidad de X: 0.0414
# Partido 33:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.9419
#   Probabilidad de 2: 0.0563
#   Probabilidad de X: 0.0018
# Partido 34:
#   Clase real: X
#   Clase predicha: X
#   Probabilidad de 1: 0.0135
#   Probabilidad de 2: 0.4484
#   Probabilidad de X: 0.5381
# Partido 35:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.7952
#   Probabilidad de 2: 0.0875
#   Probabilidad de X: 0.1173
# Partido 36:
#   Clase real: 1
#   Clase predicha: X
#   Probabilidad de 1: 0.2279
#   Probabilidad de 2: 0.0065
#   Probabilidad de X: 0.7656
# Partido 37:
#   Clase real: 2
#   Clase predicha: 2
#   Probabilidad de 1: 0.0016
#   Probabilidad de 2: 0.6833
#   Probabilidad de X: 0.3151
# Partido 38:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.9994
#   Probabilidad de 2: 0.0000
#   Probabilidad de X: 0.0005
# Partido 39:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.9678
#   Probabilidad de 2: 0.0000
#   Probabilidad de X: 0.0322
# Partido 40:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.9676
#   Probabilidad de 2: 0.0000
#   Probabilidad de X: 0.0324
# Partido 41:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.9278
#   Probabilidad de 2: 0.0487
#   Probabilidad de X: 0.0235
# Partido 42:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.4923
#   Probabilidad de 2: 0.4136
#   Probabilidad de X: 0.0940
# Partido 43:
#   Clase real: 1
#   Clase predicha: 1
#   Probabilidad de 1: 0.7209
#   Probabilidad de 2: 0.0020
#   Probabilidad de X: 0.2771
# Partido 44:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.8280
#   Probabilidad de 2: 0.1330
#   Probabilidad de X: 0.0390
# Partido 45:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.9886
#   Probabilidad de 2: 0.0096
#   Probabilidad de X: 0.0019
# Partido 46:
#   Clase real: 1
#   Clase predicha: X
#   Probabilidad de 1: 0.0336
#   Probabilidad de 2: 0.2374
#   Probabilidad de X: 0.7290
# Partido 47:
#   Clase real: 2
#   Clase predicha: X
#   Probabilidad de 1: 0.1164
#   Probabilidad de 2: 0.1488
#   Probabilidad de X: 0.7348
# Partido 48:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.6013
#   Probabilidad de 2: 0.1695
#   Probabilidad de X: 0.2292
# Partido 49:
#   Clase real: 1
#   Clase predicha: 2
#   Probabilidad de 1: 0.2618
#   Probabilidad de 2: 0.7106
#   Probabilidad de X: 0.0275
# Partido 50:
#   Clase real: X
#   Clase predicha: 2
#   Probabilidad de 1: 0.0311
#   Probabilidad de 2: 0.5640
#   Probabilidad de X: 0.4049
# Partido 51:
#   Clase real: X
#   Clase predicha: 1
#   Probabilidad de 1: 0.9985
#   Probabilidad de 2: 0.0004
#   Probabilidad de X: 0.0011
# Partido 52:
#   Clase real: 2
#   Clase predicha: 1
#   Probabilidad de 1: 0.5381
#   Probabilidad de 2: 0.3485
#   Probabilidad de X: 0.1133
